# %% [markdown]
# ### Evaluation on FIRE Dataset

# %%
import json
import pandas as pd

# %%
# FIRE Dataset - Load data files
fire_data_path = "../../datasets/fire/data"

fire_files = {
    "train": f"{fire_data_path}/fire_train.json",
    "test": f"{fire_data_path}/fire_test.json", 
    "dev": f"{fire_data_path}/fire_dev.json",
    "types": f"{fire_data_path}/fire_types.json"
}

print("FIRE dataset files:")
for split, path in fire_files.items():
    print(f"{split}: {path}")
# Out:
# FIRE dataset files:
# train: ../../datasets/fire/data/fire_train.json
# test: ../../datasets/fire/data/fire_test.json
# dev: ../../datasets/fire/data/fire_dev.json
# types: ../../datasets/fire/data/fire_types.json

# %%
# Load FIRE dataset splits
with open(fire_files["train"], 'r') as f:
    fire_train = json.load(f)
    
with open(fire_files["test"], 'r') as f:
    fire_test = json.load(f)
    
with open(fire_files["dev"], 'r') as f:
    fire_dev = json.load(f)
    
with open(fire_files["types"], 'r') as f:
    fire_types = json.load(f)

print(f"Dataset sizes: Train={len(fire_train)}, Test={len(fire_test)}, Dev={len(fire_dev)}")
# Out:
# Dataset sizes: Train=2117, Test=454, Dev=454

# %% [markdown]
# ### Data Preprocessing

# %%
def preprocess_fire_data(fire_data):
    """
    Convert FIRE dataset from tokens to sentences for multi-agent system.
    
    Each sample contains:
    - tokens: List of individual tokens  
    - entities: List with entity info
    - relations: List with relation info
    
    Returns processed data with sentence text ready for KG construction.
    """
    processed_samples = []
    
    for sample in fire_data:
        # Convert tokens to sentence
        sentence = " ".join(sample['tokens'])
        
        # Extract entities in simple format
        entities = []
        for entity in sample['entities']:
            entities.append({
                'text': entity['text'],
                'type': entity['type'],
                'start': entity['start'], 
                'end': entity['end']
            })
        
        # Extract relations in simple format
        relations = []
        for relation in sample['relations']:
            relations.append({
                'head_id': relation['head'],
                'tail_id': relation['tail'], 
                'type': relation['type']
            })
        
        processed_samples.append({
            'sentence': sentence,
            'entities': entities,
            'relations': relations,
            'orig_id': sample.get('orig_id', len(processed_samples))
        })
    
    return processed_samples

# Test preprocessing on small sample
test_sample = preprocess_fire_data(fire_train[:3])
print("Preprocessed samples:")
for i, sample in enumerate(test_sample):
    print(f"\nSample {i+1}:")
    print(f"Sentence: {sample['sentence'][:100]}...")
    print(f"Entities: {len(sample['entities'])}")
    print(f"Relations: {len(sample['relations'])}")
# Out:
# Preprocessed samples:
#
# Sample 1:
# Sentence: Albertsons and Rite Aid called off the planned merger after several advisory firms recommended votin...
# Entities: 4
# Relations: 0
#
# Sample 2:
# Sentence: EU clears merger of Essilor , Luxottica without conditions...
# Entities: 4
# Relations: 2
#
# Sample 3:
# Sentence: On February 21 , Broadcom reduced their offer to $117 billion in light of Qualcomms increased bid fo...
# Entities: 10
# Relations: 5

# %%
# Preprocess all FIRE dataset splits  
fire_train_processed = preprocess_fire_data(fire_train)
fire_test_processed = preprocess_fire_data(fire_test)
fire_dev_processed = preprocess_fire_data(fire_dev)

print("Preprocessed dataset sizes:")
print(f"Train: {len(fire_train_processed)} samples")
print(f"Test: {len(fire_test_processed)} samples") 
print(f"Dev: {len(fire_dev_processed)} samples")
# Out:
# Preprocessed dataset sizes:
# Train: 2117 samples
# Test: 454 samples
# Dev: 454 samples

# %%
fire_train_df = pd.DataFrame(fire_train_processed)
fire_test_df = pd.DataFrame(fire_test_processed)
fire_dev_df = pd.DataFrame(fire_dev_processed)

# %%
fire_train_df.iloc[:3]
# Out:
#                                             sentence  \
# 0  Albertsons and Rite Aid called off the planned...
# 1  EU clears merger of Essilor , Luxottica withou...
# 2  On February 21 , Broadcom reduced their offer ...
#
#                                             entities  \
# 0  [{'text': 'Albertsons', 'type': 'Company', 'st...
# 1  [{'text': 'EU', 'type': 'Location', 'start': 0...
# 2  [{'text': 'February 21', 'type': 'Date', 'star...
#
#                                            relations  orig_id
# 0                                                 []        0
# 1  [{'head_id': 1, 'tail_id': 3, 'type': 'Actiont...        2
# 2  [{'head_id': 2, 'tail_id': 1, 'type': 'Propert...        4

# %%
entities = [e for e in fire_types['entities']]
relations = [r for r in fire_types['relations']]

print(f"Entities: {entities}")
print(f"Relations: {relations}")
# Out:
# Entities: ['Action', 'BusinessUnit', 'Company', 'Date', 'Designation', 'FinancialEntity', 'GeopoliticalEntity', 'Location', 'Money', 'Person', 'Product', 'Quantity', 'Sector']
# Relations: ['ActionBuy', 'Actionin', 'ActionMerge', 'ActionSell', 'Actionto', 'Constituentof', 'Designation', 'Employeeof', 'Locatedin', 'Productof', 'Propertyof', 'Quantity', 'Sector', 'Subsidiaryof', 'Value', 'ValueChangeDecreaseby', 'Valuein', 'ValueChangeIncreaseby']

# %% [markdown]
# ### Initialize Evalution

# %%
import sys
import os
from datetime import datetime

# Add both the main source and current directory to path
sys.path.append('../../src')
sys.path.append('.')  # For fire_metrics in current directory

from ma_finkg.kg_construction_graph import FinancialKGConstructionGraph
from fire_metrics import evaluate_simple_baseline, calculate_fire_metrics

# Set OpenRouter API key and model
openrouter_key = "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"
model = "qwen/qwen3-30b-a3b-instruct-2507"

# Set API key and initialize
os.environ["OPENROUTER_API_KEY"] = openrouter_key
kg_system = FinancialKGConstructionGraph(model_name=model, ontology="fire", prompts="fire")

# %% [markdown]
# ### Baseline & Multi-Agent System Eval on FIRE Dataset

# %%
# Run baseline evaluation
start = datetime.now()
model_name = "qwen/qwen3-30b-a3b-instruct-2507"
print(f"Running simple {model_name} few-shot baseline...")
baseline_results = evaluate_simple_baseline(model_name, fire_test_processed, max_samples=454, entity_text_only=True)

print(f"\nSimple {model_name} Baseline Results:")
print(f"RE (Head/Relation/Tail) - P:{baseline_results['re_precision']:.3f}, R: {baseline_results['re_recall']:.3f}, F1: {baseline_results['re_f1']:.3f}")
print(f"NER - P:{baseline_results['ner_precision']:.3f}, R: {baseline_results['ner_recall']:.3f}, F1: {baseline_results['ner_f1']:.3f}")
print(f"Relation Type - P:{baseline_results['relation_type_precision']:.3f}, R: {baseline_results['relation_type_recall']:.3f}, F1: {baseline_results['relation_type_f1']:.3f}")
print(f"Samples: {baseline_results['samples']}")
end = datetime.now()
print(f"Eval Duration: {end - start}")
# Out:
# Running simple qwen/qwen3-30b-a3b-instruct-2507 few-shot baseline...
#
# === Sample 1 ===
# Text: Mr. Rooke owns and manages Rooke Fiduciary Management , a private trust company , which specializes in the investment management of publicly held securities and the oversight of a multitude of trust investments .
# Gold: [('Mr. Rooke', 'Employeeof', 'Rooke Fiduciary Management'), ('Rooke Fiduciary Management', 'Sector', 'trust')]
# Predicted: [('Rooke Fiduciary Management', 'Productof', 'investment management of publicly held securities'), ('Rooke Fiduciary Management', 'Locatedin', 'private trust company'), ('Rooke Fiduciary Management', 'Productof', 'oversight of a multitude of trust investments'), ('Mr. Rooke', 'Employeeof', 'Rooke Fiduciary Management'), ('Rooke Fiduciary Management', 'Sector', 'Financial Services')]
# TP: 1, FP: 4, FN: 1
#
# === Sample 2 ===
# Text: Pegasus s profits and losses will be distributed at 80 % to APH and 20 % to PLF .
# Gold: [('profits and losses', 'Quantity', '20 %'), ('profits and losses', 'Quantity', '80 %'), ('profits and losses', 'Propertyof', 'Pegasus')]
# Predicted: [('Pegasus', 'ValueChangeDecreaseby', '80%'), ('Pegasus', 'Productof', 'PLF'), ('Pegasus', 'ValueChangeDecreaseby', '20%'), ('Pegasus', 'Productof', 'APH'), ('APH', 'Value', '80%'), ('PLF', 'Value', '20%')]
# TP: 0, FP: 6, FN: 3
#
# === Sample 3 ===
# Text: Expenses were impacted in every category by Piedmont 's acquisition of Rowan and Crescent Financial during the year .
# Gold: [('Piedmont', 'ActionBuy', 'Rowan and Crescent Financial'), ('acquisition', 'Actionin', 'year'), ('acquisition', 'Actionto', 'Rowan and Crescent Financial')]
# Predicted: [('Piedmont', 'ActionBuy', 'Rowan'), ('Rowan', 'Subsidiaryof', 'Piedmont'), ('Piedmont', 'ActionBuy', 'Crescent Financial'), ('Acquisition', 'Actionto', 'Rowan'), ('Acquisition', 'Actionto', 'Crescent Financial'), ('Crescent Financial', 'Subsidiaryof', 'Piedmont')]
# TP: 0, FP: 6, FN: 3
# Processed 10/454
# Processed 20/454
# Processed 30/454
# Processed 40/454
# Processed 50/454
# Processed 60/454
# Processed 70/454
# Processed 80/454
# Processed 90/454
# Processed 100/454
# Processed 110/454
# Processed 120/454
# Processed 130/454
# Processed 140/454
# Processed 150/454
# Processed 160/454
# Processed 170/454
# Processed 180/454
# Processed 190/454
# Processed 200/454
# Processed 210/454
# Processed 220/454
# Processed 230/454
# Processed 240/454
# Processed 250/454
# Processed 260/454
# Processed 270/454
# Processed 280/454
# Processed 290/454
# Processed 300/454
# Processed 310/454
# Processed 320/454
# Processed 330/454
# Processed 340/454
# Processed 350/454
# Processed 360/454
# Processed 370/454
# Processed 380/454
# Processed 390/454
# Processed 400/454
# Processed 410/454
# Processed 420/454
# Processed 430/454
# Processed 440/454
# Processed 450/454
#
# Simple qwen/qwen3-30b-a3b-instruct-2507 Baseline Results:
# RE (Head/Relation/Tail) - P:0.084, R: 0.178, F1: 0.114
# NER - P:0.412, R: 0.493, F1: 0.449
# Relation Type - P:0.356, R: 0.769, F1: 0.487
# Samples: 454
# Eval Duration: 0:15:09.211246

# %%
# Run comprehensive evaluation
start_ma = datetime.now()
print("Running comprehensive NER, RE, and Triplets evaluation...")
comprehensive_results = calculate_fire_metrics(fire_test_processed, kg_system, max_samples=454, entity_text_only=True)

print(f"\n=== COMPREHENSIVE EVALUATION RESULTS (n={comprehensive_results['processed_samples']}) ===")
print(f"\nNER Metrics:")
print(f"  Precision: {comprehensive_results['ner']['precision']:.3f}")
print(f"  Recall:    {comprehensive_results['ner']['recall']:.3f}")
print(f"  F1:        {comprehensive_results['ner']['f1']:.3f}")
print(f"  (TP:{comprehensive_results['ner']['tp']}, FP:{comprehensive_results['ner']['fp']}, FN:{comprehensive_results['ner']['fn']})")

print(f"\nRE Metrics:")
print(f"  Precision: {comprehensive_results['re']['precision']:.3f}")
print(f"  Recall:    {comprehensive_results['re']['recall']:.3f}")
print(f"  F1:        {comprehensive_results['re']['f1']:.3f}")
print(f"  (TP:{comprehensive_results['re']['tp']}, FP:{comprehensive_results['re']['fp']}, FN:{comprehensive_results['re']['fn']})")

print(f"\nTriplets Metrics:")
print(f"Precision: {comprehensive_results['re']['precision']:.3f}")
print(f"Recall:    {comprehensive_results['re']['recall']:.3f}")
print(f"F1:        {comprehensive_results['re']['f1']:.3f}")
print(f"(TP:{comprehensive_results['re']['tp']}, FP:{comprehensive_results['re']['fp']}, FN:{comprehensive_results['re']['fn']})")

# Save results to file
import json
with open('comprehensive_fire_results.json', 'w') as f:
    json.dump(comprehensive_results, f, indent=2)
    
print(f"\nResults {model} saved to comprehensive_fire_results.json")
end_ma = datetime.now()
print(f"Eval Duration: {end_ma - start_ma}")
# Out:
# Running comprehensive NER, RE, and Triplets evaluation...
# Processing sample 1/454...
# [0.0s] Starting knowledge graph construction...
# [2.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.2s] Extracting entities and relations...
# [24.1s] NER completed: 10 entities
# [36.1s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 10/10 entities, 4/4 triples
# [36.6s] Finalizing results...
# [36.6s] Construction completed!
#
# === DEBUG SAMPLE 1 === [TEXT-ONLY]
# NER: Gold entities (3): ['rooke fiduciary management', 'trust', 'mr. rooke'])
# NER: Sys entities (10): ['owner', 'manages', 'manager', 'investment management', 'oversees', 'specializes', 'private trust company', 'oversight of trust investments', 'rooke fiduciary management', 'owns'])
# Gold triples (2): [('mr. rooke', 'Employeeof', 'rooke fiduciary management'), ('rooke fiduciary management', 'Sector', 'trust')]
# Sys triples (4): [('oversees', 'Actionto', 'rooke fiduciary management'), ('specializes', 'Actionto', 'rooke fiduciary management'), ('manages', 'Actionto', 'rooke fiduciary management')]
# ❌ FALSE POSITIVES (4): [('oversees', 'Actionto', 'rooke fiduciary management'), ('specializes', 'Actionto', 'rooke fiduciary management'), ('manages', 'Actionto', 'rooke fiduciary management')]
# ⭕ MISSED (2): [('mr. rooke', 'Employeeof', 'rooke fiduciary management'), ('rooke fiduciary management', 'Sector', 'trust')]
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.2s] Extracting entities and relations...
# [18.7s] NER completed: 4 entities
# [37.3s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [38.7s] Finalizing results...
# [38.7s] Construction completed!
#
# === DEBUG SAMPLE 2 === [TEXT-ONLY]
# NER: Gold entities (6): ['profits and losses', 'aph', '80 %', 'plf', 'pegasus', '20 %'])
# NER: Sys entities (4): ['aph', 'plf', '80 %', '20 %'])
# Gold triples (3): [('profits and losses', 'Propertyof', 'pegasus'), ('profits and losses', 'Quantity', '20 %'), ('profits and losses', 'Quantity', '80 %')]
# Sys triples (6): [('aph', 'ValueChangeIncreaseby', '80 %'), ('aph', 'ValueChangeIncreaseby', '20 %'), ('plf', 'Quantity', '20 %')]
# ❌ FALSE POSITIVES (6): [('aph', 'ValueChangeIncreaseby', '80 %'), ('aph', 'ValueChangeIncreaseby', '20 %'), ('plf', 'Quantity', '20 %')]
# ⭕ MISSED (3): [('profits and losses', 'Propertyof', 'pegasus'), ('profits and losses', 'Quantity', '20 %'), ('profits and losses', 'Quantity', '80 %')]
# [0.0s] Starting knowledge graph construction...
# [3.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.9s] Extracting entities and relations...
# [23.6s] NER completed: 4 entities
# [31.5s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [35.3s] Finalizing results...
# [35.3s] Construction completed!
#
# === DEBUG SAMPLE 3 === [TEXT-ONLY]
# NER: Gold entities (5): ['expenses', 'year', 'rowan and crescent financial', 'acquisition', 'piedmont'])
# NER: Sys entities (4): ['acquisition', 'crescent financial', 'piedmont', 'rowan'])
# Gold triples (3): [('acquisition', 'Actionto', 'rowan and crescent financial'), ('acquisition', 'Actionin', 'year'), ('piedmont', 'ActionBuy', 'rowan and crescent financial')]
# Sys triples (2): [('acquisition', 'Actionto', 'rowan'), ('acquisition', 'Actionto', 'crescent financial')]
# ❌ FALSE POSITIVES (2): [('acquisition', 'Actionto', 'rowan'), ('acquisition', 'Actionto', 'crescent financial')]
# ⭕ MISSED (3): [('acquisition', 'Actionto', 'rowan and crescent financial'), ('acquisition', 'Actionin', 'year'), ('piedmont', 'ActionBuy', 'rowan and crescent financial')]
# [0.0s] Starting knowledge graph construction...
# [1.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.9s] Extracting entities and relations...
# [23.9s] NER completed: 5 entities
# [61.4s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [65.0s] Finalizing results...
# [65.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.3s] Extracting entities and relations...
# [17.7s] NER completed: 2 entities
# [33.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [34.6s] Finalizing results...
# [34.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.4s] Extracting entities and relations...
# [18.2s] NER completed: 6 entities
# [36.4s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 6/6 entities, 3/3 triples
# [38.5s] Finalizing results...
# [38.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.2s] Extracting entities and relations...
# [22.2s] NER completed: 5 entities
# [58.3s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 5/5 entities, 1/1 triples
# [59.8s] Finalizing results...
# [59.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.2s] Extracting entities and relations...
# [25.4s] NER completed: 5 entities
# [42.0s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 5/5 entities, 1/1 triples
# [44.3s] Finalizing results...
# [44.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.1s] Extracting entities and relations...
# [17.3s] NER completed: 5 entities
# [42.6s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [44.0s] Finalizing results...
# [44.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.8s] Extracting entities and relations...
# [19.0s] NER completed: 1 entities
# [19.0s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [20.3s] Finalizing results...
# [20.3s] Construction completed!
# Processing sample 11/454...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.4s] Extracting entities and relations...
# [22.8s] NER completed: 11 entities
# [47.3s] RE completed: 27 filtered triples
#
# [REVISION] Validated: 11/11 entities, 27/27 triples
# [49.0s] Finalizing results...
# [49.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.9s] Extracting entities and relations...
# [20.4s] NER completed: 5 entities
# [44.3s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 5/5 entities, 1/1 triples
# [45.0s] Finalizing results...
# [45.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.0s] Extracting entities and relations...
# [19.8s] NER completed: 6 entities
# [51.5s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 6/6 entities, 10/10 triples
# [53.1s] Finalizing results...
# [53.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.9s] Extracting entities and relations...
# [21.2s] NER completed: 13 entities
# [90.8s] RE completed: 21 filtered triples
#
# [REVISION] Validated: 13/13 entities, 21/21 triples
# [93.5s] Finalizing results...
# [93.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [8.2s] Extracting entities and relations...
# [34.4s] NER completed: 3 entities
# [59.0s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [59.5s] Finalizing results...
# [59.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.3s] Extracting entities and relations...
# [34.0s] NER completed: 5 entities
# [69.0s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [69.6s] Finalizing results...
# [69.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.9s] Extracting entities and relations...
# [35.2s] NER completed: 8 entities
# [133.4s] RE completed: 17 filtered triples
#
# [REVISION] Validated: 8/8 entities, 17/17 triples
# [134.3s] Finalizing results...
# [134.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.6s] Extracting entities and relations...
# [39.5s] NER completed: 6 entities
# [87.8s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 6/6 entities, 10/10 triples
# [91.2s] Finalizing results...
# [91.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [8.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [10.0s] Extracting entities and relations...
# [47.3s] NER completed: 6 entities
# [86.3s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 6/6 entities, 4/4 triples
# [87.4s] Finalizing results...
# [87.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [6.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [8.2s] Extracting entities and relations...
# [42.1s] NER completed: 11 entities
# [69.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 11/11 entities, 0/0 triples
# [70.2s] Finalizing results...
# [70.2s] Construction completed!
# Processing sample 21/454...
# [0.0s] Starting knowledge graph construction...
# [4.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.8s] Extracting entities and relations...
# [32.8s] NER completed: 8 entities
# [93.9s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 8/8 entities, 12/12 triples
# [94.6s] Finalizing results...
# [94.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.5s] Extracting entities and relations...
# [21.9s] NER completed: 2 entities
# [47.1s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 2/2 entities, 1/1 triples
# [48.5s] Finalizing results...
# [48.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.5s] Extracting entities and relations...
# [26.1s] NER completed: 4 entities
# [33.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [33.7s] Finalizing results...
# [33.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.2s] Extracting entities and relations...
# [33.9s] NER completed: 7 entities
# [64.2s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 7/7 entities, 3/3 triples
# [68.3s] Finalizing results...
# [68.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.7s] Extracting entities and relations...
# [36.4s] NER completed: 6 entities
# [66.3s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 6/6 entities, 5/5 triples
# [68.5s] Finalizing results...
# [68.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.4s] Extracting entities and relations...
# [32.5s] NER completed: 4 entities
# [73.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [76.4s] Finalizing results...
# [76.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.1s] Extracting entities and relations...
# [33.9s] NER completed: 5 entities
# [37.1s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [41.2s] Finalizing results...
# [41.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [6.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [7.2s] Extracting entities and relations...
# [29.7s] NER completed: 6 entities
# [29.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 6/6 entities, 0/0 triples
# [32.1s] Finalizing results...
# [32.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.2s] Extracting entities and relations...
# [27.3s] NER completed: 5 entities
# [65.7s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [71.6s] Finalizing results...
# [71.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.8s] Extracting entities and relations...
# [32.4s] NER completed: 6 entities
# [89.4s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 6/6 entities, 10/10 triples
# [101.2s] Finalizing results...
# [101.2s] Construction completed!
# Processing sample 31/454...
# [0.0s] Starting knowledge graph construction...
# [3.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.6s] Extracting entities and relations...
# [57.1s] NER completed: 9 entities
# [57.1s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 9/9 entities, 0/0 triples
# [66.1s] Finalizing results...
# [66.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [5.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.6s] Extracting entities and relations...
# [33.4s] NER completed: 5 entities
# [56.9s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [57.5s] Finalizing results...
# [57.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.1s] Extracting entities and relations...
# [19.8s] NER completed: 4 entities
# [19.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [21.5s] Finalizing results...
# [21.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.0s] Extracting entities and relations...
# [22.8s] NER completed: 10 entities
# [46.5s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 10/10 entities, 1/1 triples
# [47.1s] Finalizing results...
# [47.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.4s] Extracting entities and relations...
# [21.7s] NER completed: 3 entities
# [27.9s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [29.2s] Finalizing results...
# [29.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.7s] Extracting entities and relations...
# [19.9s] NER completed: 2 entities
# [25.5s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 2/2 entities, 1/1 triples
# [28.4s] Finalizing results...
# [28.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.5s] Extracting entities and relations...
# [28.4s] NER completed: 5 entities
# [51.3s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [51.9s] Finalizing results...
# [51.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.5s] Extracting entities and relations...
# [24.2s] NER completed: 4 entities
# [46.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [47.2s] Finalizing results...
# [47.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.7s] Extracting entities and relations...
# [25.5s] NER completed: 5 entities
# [56.0s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [56.5s] Finalizing results...
# [56.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.4s] Extracting entities and relations...
# [22.1s] NER completed: 2 entities
# [34.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [35.5s] Finalizing results...
# [35.5s] Construction completed!
# Processing sample 41/454...
# [0.0s] Starting knowledge graph construction...
# [1.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.2s] Extracting entities and relations...
# [20.0s] NER completed: 7 entities
# [38.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 7/7 entities, 2/2 triples
# [39.6s] Finalizing results...
# [39.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.6s] Extracting entities and relations...
# [22.0s] NER completed: 5 entities
# [40.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [42.3s] Finalizing results...
# [42.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.7s] Extracting entities and relations...
# [22.8s] NER completed: 4 entities
# [28.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [31.1s] Finalizing results...
# [31.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.3s] Extracting entities and relations...
# [19.6s] NER completed: 1 entities
# [19.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [20.8s] Finalizing results...
# [20.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.4s] Extracting entities and relations...
# [27.3s] NER completed: 3 entities
# [44.0s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [45.0s] Finalizing results...
# [45.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.5s] Extracting entities and relations...
# [17.6s] NER completed: 7 entities
# [33.7s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 7/7 entities, 4/4 triples
# [34.9s] Finalizing results...
# [34.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [8.0s] Extracting entities and relations...
# [26.9s] NER completed: 7 entities
# [46.8s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 7/7 entities, 5/5 triples
# [48.6s] Finalizing results...
# [48.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.7s] Extracting entities and relations...
# [20.3s] NER completed: 6 entities
# [70.6s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [72.5s] Finalizing results...
# [72.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.4s] Extracting entities and relations...
# [23.2s] NER completed: 4 entities
# [32.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [34.7s] Finalizing results...
# [34.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.2s] Extracting entities and relations...
# [25.5s] NER completed: 5 entities
# [57.2s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [58.8s] Finalizing results...
# [58.8s] Construction completed!
# Processing sample 51/454...
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.9s] Extracting entities and relations...
# [23.0s] NER completed: 3 entities
# [54.4s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 3/3 entities, 2/2 triples
# [58.0s] Finalizing results...
# [58.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.0s] Extracting entities and relations...
# [37.4s] NER completed: 10 entities
# [98.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 10/10 entities, 2/2 triples
# [100.5s] Finalizing results...
# [100.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [4.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.2s] Extracting entities and relations...
# [24.9s] NER completed: 6 entities
# [54.8s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 6/6 entities, 4/4 triples
# [56.6s] Finalizing results...
# [56.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.1s] Extracting entities and relations...
# [19.3s] NER completed: 10 entities
# [56.5s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 10/10 entities, 3/3 triples
# [57.7s] Finalizing results...
# [57.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.4s] Extracting entities and relations...
# [23.2s] NER completed: 2 entities
# [23.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [25.8s] Finalizing results...
# [25.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.3s] Extracting entities and relations...
# [38.7s] NER completed: 3 entities
# [62.9s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [65.1s] Finalizing results...
# [65.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [11.2s] Extracting entities and relations...
# [47.6s] NER completed: 5 entities
# [50.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [54.2s] Finalizing results...
# [54.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.2s] Extracting entities and relations...
# [45.3s] NER completed: 3 entities
# [45.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [46.8s] Finalizing results...
# [46.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.7s] Extracting entities and relations...
# [27.2s] NER completed: 2 entities
# [32.0s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [32.8s] Finalizing results...
# [32.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.4s] Extracting entities and relations...
# [25.4s] NER completed: 3 entities
# [28.0s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [31.4s] Finalizing results...
# [31.4s] Construction completed!
# Processing sample 61/454...
# [0.0s] Starting knowledge graph construction...
# [3.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.1s] Extracting entities and relations...
# [31.1s] NER completed: 7 entities
# [31.2s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 7/7 entities, 0/0 triples
# [31.7s] Finalizing results...
# [31.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.9s] Extracting entities and relations...
# [22.8s] NER completed: 6 entities
# [86.1s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 6/6 entities, 1/1 triples
# [90.4s] Finalizing results...
# [90.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.6s] Extracting entities and relations...
# [21.8s] NER completed: 4 entities
# [25.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [26.4s] Finalizing results...
# [26.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.9s] Extracting entities and relations...
# [23.7s] NER completed: 5 entities
# [80.3s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [82.8s] Finalizing results...
# [82.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [4.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.7s] Extracting entities and relations...
# [39.2s] NER completed: 2 entities
# [76.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [77.0s] Finalizing results...
# [77.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.1s] Extracting entities and relations...
# [26.4s] NER completed: 4 entities
# [81.5s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [84.3s] Finalizing results...
# [84.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.7s] Extracting entities and relations...
# [31.0s] NER completed: 5 entities
# [49.6s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [53.4s] Finalizing results...
# [53.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [7.0s] Extracting entities and relations...
# [31.0s] NER completed: 2 entities
# [40.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [42.1s] Finalizing results...
# [42.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.6s] Extracting entities and relations...
# [35.3s] NER completed: 6 entities
# [44.5s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 6/6 entities, 1/1 triples
# [46.2s] Finalizing results...
# [46.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.6s] Extracting entities and relations...
# [28.9s] NER completed: 4 entities
# [36.6s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 4/4 entities, 1/1 triples
# [38.3s] Finalizing results...
# [38.3s] Construction completed!
# Processing sample 71/454...
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.0s] Extracting entities and relations...
# [26.4s] NER completed: 6 entities
# [38.1s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 6/6 entities, 1/1 triples
# [39.5s] Finalizing results...
# [39.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.2s] Extracting entities and relations...
# [24.5s] NER completed: 6 entities
# [45.1s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 6/6 entities, 0/0 triples
# [47.0s] Finalizing results...
# [47.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [4.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.9s] Extracting entities and relations...
# [29.7s] NER completed: 7 entities
# [64.3s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 7/7 entities, 7/7 triples
# [64.9s] Finalizing results...
# [64.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.2s] Extracting entities and relations...
# [29.8s] NER completed: 3 entities
# [57.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [60.0s] Finalizing results...
# [60.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.3s] Extracting entities and relations...
# [24.7s] NER completed: 5 entities
# [29.6s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [32.6s] Finalizing results...
# [32.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [7.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [9.7s] Extracting entities and relations...
# [30.3s] NER completed: 8 entities
# [56.5s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 8/8 entities, 6/6 triples
# [58.0s] Finalizing results...
# [58.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.5s] Extracting entities and relations...
# [27.6s] NER completed: 2 entities
# [43.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [48.1s] Finalizing results...
# [48.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.7s] Extracting entities and relations...
# [36.2s] NER completed: 7 entities
# [130.3s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 7/7 entities, 1/1 triples
# [131.3s] Finalizing results...
# [131.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.9s] Extracting entities and relations...
# [30.6s] NER completed: 5 entities
# [43.1s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/5 triples
# [44.9s] Finalizing results...
# [44.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.4s] Extracting entities and relations...
# [17.4s] NER completed: 3 entities
# [18.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [19.5s] Finalizing results...
# [19.6s] Construction completed!
# Processing sample 81/454...
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.3s] Extracting entities and relations...
# [17.3s] NER completed: 6 entities
# [48.9s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 6/6 entities, 5/5 triples
# [49.8s] Finalizing results...
# [49.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.3s] Extracting entities and relations...
# [27.3s] NER completed: 2 entities
# [40.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [43.0s] Finalizing results...
# [43.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.2s] Extracting entities and relations...
# [35.0s] NER completed: 4 entities
# [76.7s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 4/4 entities, 7/7 triples
# [78.2s] Finalizing results...
# [78.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.7s] Extracting entities and relations...
# [25.5s] NER completed: 4 entities
# [55.9s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [64.7s] Finalizing results...
# [64.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.0s] Extracting entities and relations...
# [26.9s] NER completed: 5 entities
# [69.9s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 5/5 entities, 5/5 triples
# [75.3s] Finalizing results...
# [75.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.1s] Extracting entities and relations...
# [19.8s] NER completed: 2 entities
# [19.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.4s] Extracting entities and relations...
# [38.7s] NER completed: 6 entities
# [63.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 6/6 entities, 2/2 triples
# [67.8s] Finalizing results...
# [67.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.1s] Extracting entities and relations...
# [31.7s] NER completed: 3 entities
# [31.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [35.6s] Finalizing results...
# [35.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.2s] Extracting entities and relations...
# [27.0s] NER completed: 2 entities
# [51.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [54.0s] Finalizing results...
# [54.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.6s] Extracting entities and relations...
# [26.1s] NER completed: 6 entities
# [55.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [58.0s] Finalizing results...
# [58.0s] Construction completed!
# Processing sample 91/454...
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.6s] Extracting entities and relations...
# [28.7s] NER completed: 1 entities
# [28.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [30.2s] Finalizing results...
# [30.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.0s] Extracting entities and relations...
# [27.3s] NER completed: 6 entities
# [32.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 6/6 entities, 0/0 triples
# [34.3s] Finalizing results...
# [34.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.3s] Extracting entities and relations...
# [28.0s] NER completed: 10 entities
# [60.4s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 10/10 entities, 2/2 triples
# [62.1s] Finalizing results...
# [62.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.6s] Extracting entities and relations...
# [25.1s] NER completed: 5 entities
# [25.1s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [25.8s] Finalizing results...
# [25.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.8s] Extracting entities and relations...
# [27.8s] NER completed: 7 entities
# [58.3s] RE completed: 2 filtered triples
#
# ...
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [24.6s] Finalizing results...
# [24.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.9s] Extracting entities and relations...
# [23.8s] NER completed: 7 entities
# [30.9s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 7/7 entities, 1/1 triples
# [31.7s] Finalizing results...
# [31.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.8s] Extracting entities and relations...
# [26.1s] NER completed: 3 entities
# [26.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [19759.5s] Finalizing results...
# [19760.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [16.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [24.3s] Extracting entities and relations...
# [61.3s] NER completed: 2 entities
# [61.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [66.4s] Finalizing results...
# [66.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [4.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.8s] Extracting entities and relations...
# [48.9s] NER completed: 3 entities
# [84.6s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [86.7s] Finalizing results...
# [86.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [10.2s] Extracting entities and relations...
# [37.9s] NER completed: 3 entities
# [68.7s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [74.6s] Finalizing results...
# [74.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [8.4s] Extracting entities and relations...
# [43.8s] NER completed: 5 entities
# [70.6s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 5/5 entities, 1/1 triples
# [76.7s] Finalizing results...
# [76.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.5s] Extracting entities and relations...
# [36.9s] NER completed: 2 entities
# [45.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [51.4s] Finalizing results...
# [51.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [5.3s] Extracting entities and relations...
# [44.4s] NER completed: 7 entities
# [75.1s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 7/7 entities, 5/5 triples
# [77.0s] Finalizing results...
# [77.1s] Construction completed!
# Processing sample 431/454...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.9s] Extracting entities and relations...
# [29.9s] NER completed: 4 entities
# [29.9s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [30.6s] Finalizing results...
# [30.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [5.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [7.2s] Extracting entities and relations...
# [44.6s] NER completed: 8 entities
# [77.8s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 8/8 entities, 4/4 triples
# [79.7s] Finalizing results...
# [79.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.9s] Extracting entities and relations...
# [42.8s] NER completed: 4 entities
# [65.4s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [66.9s] Finalizing results...
# [66.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.7s] Extracting entities and relations...
# [36.1s] NER completed: 5 entities
# [98.8s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [104.8s] Finalizing results...
# [104.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.8s] Extracting entities and relations...
# [46.5s] NER completed: 4 entities
# [46.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [54.0s] Finalizing results...
# [54.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [8.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [11.4s] Extracting entities and relations...
# [44.8s] NER completed: 7 entities
# [146.9s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 7/7 entities, 9/9 triples
# [148.6s] Finalizing results...
# [148.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [10.1s] Extracting entities and relations...
# [41.7s] NER completed: 9 entities
# [119.9s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 9/9 entities, 9/9 triples
# [120.5s] Finalizing results...
# [120.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [4.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [7.7s] Extracting entities and relations...
# [53.5s] NER completed: 6 entities
# [89.9s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [94.6s] Finalizing results...
# [94.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.4s] Extracting entities and relations...
# [24.8s] NER completed: 5 entities
# [49.5s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 5/5 entities, 5/5 triples
# [51.2s] Finalizing results...
# [51.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.9s] Extracting entities and relations...
# [20.2s] NER completed: 2 entities
# [45.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [46.8s] Finalizing results...
# [46.8s] Construction completed!
# Processing sample 441/454...
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.3s] Extracting entities and relations...
# [25.3s] NER completed: 2 entities
# [50.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [52.7s] Finalizing results...
# [52.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [6.4s] Extracting entities and relations...
# [31.8s] NER completed: 7 entities
# [37.8s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 7/7 entities, 2/2 triples
# [40.8s] Finalizing results...
# [40.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.2s] Extracting entities and relations...
# [29.2s] NER completed: 4 entities
# [52.7s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 4/4 entities, 3/3 triples
# [54.5s] Finalizing results...
# [54.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.4s] Extracting entities and relations...
# [26.9s] NER completed: 2 entities
# [47.9s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [49.5s] Finalizing results...
# [49.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [7.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [9.8s] Extracting entities and relations...
# [28.9s] NER completed: 4 entities
# [49.2s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 4/4 entities, 3/3 triples
# [51.6s] Finalizing results...
# [51.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.3s] Extracting entities and relations...
# [29.3s] NER completed: 6 entities
# [53.2s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 6/6 entities, 4/4 triples
# [53.8s] Finalizing results...
# [53.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.9s] Extracting entities and relations...
# [22.4s] NER completed: 2 entities
# [51.2s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [52.9s] Finalizing results...
# [52.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [3.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [4.9s] Extracting entities and relations...
# [27.5s] NER completed: 5 entities
# [36.1s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [38.5s] Finalizing results...
# [38.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [2.5s] Extracting entities and relations...
# [21.3s] NER completed: 3 entities
# [42.3s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 3/3 entities, 2/2 triples
# [43.1s] Finalizing results...
# [43.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.5s] Extracting entities and relations...
# [28.4s] NER completed: 14 entities
# [82.0s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 14/14 entities, 11/11 triples
# [83.4s] Finalizing results...
# [83.4s] Construction completed!
# Processing sample 451/454...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [12.5s] Extracting entities and relations...
# [51.2s] NER completed: 4 entities
# [108.8s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 4/4 entities, 8/8 triples
# [109.4s] Finalizing results...
# [109.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [6.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [8.9s] Extracting entities and relations...
# [57.6s] NER completed: 3 entities
# [78.6s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 3/3 entities, 1/1 triples
# [81.1s] Finalizing results...
# [81.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [3.0s] Extracting entities and relations...
# [60.6s] NER completed: 7 entities
# [156.6s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 7/7 entities, 3/3 triples
# [162.4s] Finalizing results...
# [162.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined fire ontology
# [1.9s] Extracting entities and relations...
# [73.8s] NER completed: 8 entities
# [148.3s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 8/8 entities, 7/7 triples
# [155.5s] Finalizing results...
# [155.5s] Construction completed!
#
# === COMPREHENSIVE EVALUATION RESULTS (n=454) ===
#
# NER Metrics:
#   Precision: 0.531
#   Recall:    0.602
#   F1:        0.565
#   (TP:1305, FP:1152, FN:861)
#
# RE Metrics:
#   Precision: 0.129
#   Recall:    0.166
#   F1:        0.145
#   (TP:200, FP:1351, FN:1008)
#
# Triplets Metrics:
# Precision: 0.129
# Recall:    0.166
# F1:        0.145
# (TP:200, FP:1351, FN:1008)
#
# Results qwen/qwen3-30b-a3b-instruct-2507 saved to comprehensive_fire_results.json
# Eval Duration: 12:24:06.023289

# %%
# Results Comparison Table

import pandas as pd

# Create comparison dataframe
results_data = []

# Add baseline results
if 'baseline_results' in locals():
    results_data.append({
        'System':  model + " " + model_name + ' Baseline',
        'NER_P': baseline_results['ner_precision'],
        'NER_R': baseline_results['ner_recall'],
        'NER_F1': baseline_results['ner_f1'],
        'RE_P': baseline_results['re_precision'],
        'RE_R': baseline_results['re_recall'],
        'RE_F1': baseline_results['re_f1'],
        'RelType_P': baseline_results['relation_type_precision'],
        'RelType_R': baseline_results['relation_type_recall'],
        'RelType_F1': baseline_results['relation_type_f1']
    })

# Add multi-agent results
results_data.append({
    'System': 'Multi-Agent System',
    'NER_P': comprehensive_results['ner']['precision'],
    'NER_R': comprehensive_results['ner']['recall'],
    'NER_F1': comprehensive_results['ner']['f1'],
    'RE_P': comprehensive_results['re']['precision'],
    'RE_R': comprehensive_results['re']['recall'],
    'RE_F1': comprehensive_results['re']['f1'],
    'RelType_P': comprehensive_results['relation_type']['precision'],
    'RelType_R': comprehensive_results['relation_type']['recall'],
    'RelType_F1': comprehensive_results['relation_type']['f1']
})

# Create and display comparison table
comparison_df = pd.DataFrame(results_data)
comparison_df = comparison_df.round(3)

print("=== FIRE EVALUATION COMPARISON ===")
print(comparison_df.to_string(index=False))

# Detailed breakdown for multi-agent system
print(f"\n=== DETAILED MULTI-AGENT BREAKDOWN ===")
print(f"Samples processed: {comprehensive_results['processed_samples']}")
print(f"\nNER (Entity Extraction):")
print(f"  True Positives:  {comprehensive_results['ner']['tp']}")
print(f"  False Positives: {comprehensive_results['ner']['fp']}")
print(f"  False Negatives: {comprehensive_results['ner']['fn']}")

print(f"\nRE (Relation Extraction):")
print(f"  True Positives:  {comprehensive_results['re']['tp']}")
print(f"  False Positives: {comprehensive_results['re']['fp']}")
print(f"  False Negatives: {comprehensive_results['re']['fn']}")

print(f"\nRelation Types:")
print(f"  True Positives:  {comprehensive_results['relation_type']['tp']}")
print(f"  False Positives: {comprehensive_results['relation_type']['fp']}")
print(f"  False Negatives: {comprehensive_results['relation_type']['fn']}")

# Save comparison table
comparison_df.to_csv('fire_evaluation_comparison.csv', index=False)
print(f"\nComparison table saved to fire_evaluation_comparison.csv")
# Out:
# === FIRE EVALUATION COMPARISON ===
#                                                                     System  NER_P  NER_R  NER_F1  RE_P  RE_R  RE_F1  RelType_P  RelType_R  RelType_F1
# qwen/qwen3-30b-a3b-instruct-2507 qwen/qwen3-30b-a3b-instruct-2507 Baseline  0.412  0.493   0.449 0.084 0.178  0.114      0.356      0.769       0.487
#                                                         Multi-Agent System  0.531  0.602   0.565 0.129 0.166  0.145      0.382      0.355       0.368
#
# === DETAILED MULTI-AGENT BREAKDOWN ===
# Samples processed: 454
#
# NER (Entity Extraction):
#   True Positives:  1305
#   False Positives: 1152
#   False Negatives: 861
#
# RE (Relation Extraction):
#   True Positives:  200
#   False Positives: 1351
#   False Negatives: 1008
#
# Relation Types:
#   True Positives:  306
#   False Positives: 494
#   False Negatives: 557
#
# Comparison table saved to fire_evaluation_comparison.csv
