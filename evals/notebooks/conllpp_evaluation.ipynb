# %% [markdown]
# ### NER Evaluation (Conllpp)

# %%
# %pip install "datasets<4.0.0" "huggingface_hub<1.0.0"

# %%
import sys
import os
sys.path.append('.')

from datasets import load_dataset
from ma_finkg.kg_construction_graph import FinancialKGConstructionGraph
from ma_finkg.utils import set_global_timer

# Set OpenRouter API key and model
openrouter_key = ""
model = "openai/gpt-3.5-turbo"

# Set API key and initialize
os.environ["OPENROUTER_API_KEY"] = openrouter_key
kg_system = FinancialKGConstructionGraph(model_name=model, ontology="conllpp", prompts="conllpp", enable_re=False)

# Load actual datasets
print("Loading Conllpp...")
conllpp_dataset = load_dataset("ZihanWangKi/conllpp")
# Out:
# Loading Conllpp...

# %% [markdown]
# ### Conllpp NER Test

# %%
print(f"Train: {conllpp_dataset['train']}")
print(f"Validation: {conllpp_dataset['validation']}")
print(f"Test: {conllpp_dataset['test']}")
# Out:
# Train: Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 14041
# })
# Validation: Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 3250
# })
# Test: Dataset({
#     features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#     num_rows: 3453
# })

# %%
id2ner = {
    0: 'O',
    1: 'B-PER', 2: 'I-PER',
    3: 'B-ORG', 4: 'I-ORG',
    5: 'B-LOC', 6: 'I-LOC',
    7: 'B-MISC', 8: 'I-MISC'
}
tokens = conllpp_dataset['test'][4]['tokens']
ner_tags = conllpp_dataset['test'][4]['ner_tags']
text = ' '.join(tokens)
text
# Out:
# 'But China saw their luck desert them in the second match of the group , crashing to a surprise 2-0 defeat to newcomers Uzbekistan .'

# %%
entities = []
current = None

for token, tag_id in zip(tokens, ner_tags):
    tag = id2ner[tag_id]
    if tag.startswith('B-'):
        # finish previous
        if current:
            entities.append(current)
        current = {'type': tag[2:], 'text': token}
    elif tag.startswith('I-') and current and tag[2:]==current['type']:
        current['text'] += ' ' + token
    else:
        if current:
            entities.append(current)
            current = None

# catch last
if current:
    entities.append(current)

entities
# Out:
# [{'type': 'LOC', 'text': 'China'}, {'type': 'LOC', 'text': 'Uzbekistan'}]

# %% [markdown]
# ### Conllpp Micro F1 Evaluation

# %%
# Evaluate on first 100 test samples with batching and JSON saving
import json
from pathlib import Path

rows = 50  # Change to 3453 for full evaluation (test set size) 
batch_size = 5
results_file = "conll_evaluation.json"

# Load existing progress if resuming
results_path = Path(results_file)
if results_path.exists():
    with open(results_path, 'r') as f:
        saved_data = json.load(f)
    start_idx = saved_data.get('processed_samples', 0)
    total_tp = saved_data.get('total_tp', 0)
    total_fp = saved_data.get('total_fp', 0) 
    total_fn = saved_data.get('total_fn', 0)
    print(f"Resuming from sample {start_idx}")
else:
    start_idx = 0
    total_tp = total_fp = total_fn = 0

all_gold_set = []
all_sys_set = []

for i in range(start_idx, rows):
    sample = conllpp_dataset['test'][i]
    text = ' '.join(sample['tokens'])
    
    # Get gold entities (reuse existing logic)
    entities = []
    current = None
    for token, tag_id in zip(sample['tokens'], sample['ner_tags']):
        tag = id2ner[tag_id]
        if tag.startswith('B-'):
            if current: entities.append(current)
            current = {'type': tag[2:], 'text': token}
        elif tag.startswith('I-') and current and tag[2:]==current['type']:
            current['text'] += ' ' + token
        else:
            if current: entities.append(current); current = None
    if current: entities.append(current)
    
    gold_set = set((e['text'].lower(), e['type']) for e in entities)
    all_gold_set.append(gold_set)
    
    # System extraction
    print(f"Processing sample {i+1}/{rows}...")
    
    result = kg_system.construct_kg(text)
    sys_entities = result['finalize'].get("revised_entities", []) if 'finalize' in result else []
    sys_set = set((e.text.lower(), e.entity_type) for e in sys_entities)
    
    # Only append non-empty sys_set to avoid skewing evaluation metrics
    if sys_set:
        all_sys_set.append(sys_set)
    else:
        all_sys_set.append(set())  # Keep alignment with gold sets

    tp = len(gold_set & sys_set)
    fp = len(sys_set - gold_set) 
    fn = len(gold_set - sys_set)

    total_tp += tp
    total_fp += fp
    total_fn += fn

    # Save progress every batch_size samples
    if (i + 1) % batch_size == 0 or (i + 1) == rows:
        save_data = {
            'processed_samples': i + 1,
            'total_tp': total_tp,
            'total_fp': total_fp,
            'total_fn': total_fn
        }
        with open(results_path, 'w') as f:
            json.dump(save_data, f)
        print(f"Progress saved: {i+1}/{rows}")

    if i % 20 == 0: print(f"Sample {i+1}/{rows}]")

print(f"FINAL EXTRACTION: {sum(len(s) for s in all_sys_set)} System Entities, {sum(len(s) for s in all_gold_set)} Gold Entities")
print("Saved Final Triples to JSON files")
with open("all_sys_set.json", 'w') as f:
    json.dump([list(s) for s in all_sys_set], f)
with open("all_gold_set.json", 'w') as f:
    json.dump([list(s) for s in all_gold_set], f)
# Out:
# Processing sample 1/50...
# [0.0s] Starting knowledge graph construction...
# [2.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.3s] Extracting entities and relations...
# [12.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [13.3s] Finalizing results...
# [13.3s] Construction completed!
# Sample 1/50]
# Processing sample 2/50...
# [0.0s] Starting knowledge graph construction...
# [7.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [8.3s] Extracting entities and relations...
# [11.3s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [12.4s] Finalizing results...
# [12.4s] Construction completed!
# Processing sample 3/50...
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.4s] Extracting entities and relations...
# [16.2s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [19.8s] Extracting entities and relations...
# [24.2s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [26.0s] Finalizing results...
# [26.0s] Construction completed!
# Processing sample 4/50...
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.1s] Extracting entities and relations...
# [8.3s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [10.9s] Finalizing results...
# [10.9s] Construction completed!
# Processing sample 5/50...
# [0.0s] Starting knowledge graph construction...
# [2.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [6.8s] Extracting entities and relations...
# [11.3s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [12.1s] Finalizing results...
# [12.1s] Construction completed!
# Progress saved: 5/50
# Processing sample 6/50...
# [0.0s] Starting knowledge graph construction...
# [3.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [13.5s] Extracting entities and relations...
# [19.6s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [22.0s] Finalizing results...
# [22.0s] Construction completed!
# Processing sample 7/50...
# [0.0s] Starting knowledge graph construction...
# [2.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [6.0s] Extracting entities and relations...
# [10.9s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [12.6s] Finalizing results...
# [12.6s] Construction completed!
# Processing sample 8/50...
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.9s] Extracting entities and relations...
# [8.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [9.1s] Finalizing results...
# [9.1s] Construction completed!
# Processing sample 9/50...
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.2s] Extracting entities and relations...
# [8.6s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [12.9s] Finalizing results...
# [12.9s] Construction completed!
# Processing sample 10/50...
# [0.0s] Starting knowledge graph construction...
# [2.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.4s] Extracting entities and relations...
# [15.1s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [16.7s] Finalizing results...
# [16.7s] Construction completed!
# Progress saved: 10/50
# Processing sample 11/50...
# [0.0s] Starting knowledge graph construction...
# [2.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.9s] Extracting entities and relations...
# [16.9s] NER completed: 3 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [18.5s] Finalizing results...
# [18.5s] Construction completed!
# Processing sample 12/50...
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.2s] Extracting entities and relations...
# [8.4s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [10.0s] Finalizing results...
# [10.0s] Construction completed!
# Processing sample 13/50...
# [0.0s] Starting knowledge graph construction...
# [4.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [5.5s] Extracting entities and relations...
# [9.3s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [10.7s] Finalizing results...
# [10.7s] Construction completed!
# Processing sample 14/50...
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.2s] Extracting entities and relations...
# [10.1s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [11.6s] Finalizing results...
# [11.6s] Construction completed!
# Processing sample 15/50...
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.9s] Extracting entities and relations...
# [8.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [12.7s] Finalizing results...
# [12.7s] Construction completed!
# Progress saved: 15/50
# Processing sample 16/50...
# [0.0s] Starting knowledge graph construction...
# [3.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [6.7s] Extracting entities and relations...
# [10.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [12.2s] Finalizing results...
# [12.2s] Construction completed!
# Processing sample 17/50...
# [0.0s] Starting knowledge graph construction...
# [3.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.8s] Extracting entities and relations...
# [14.0s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [15.8s] Finalizing results...
# [15.8s] Construction completed!
# Processing sample 18/50...
# [0.0s] Starting knowledge graph construction...
# [2.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.3s] Extracting entities and relations...
# [7.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [9.2s] Finalizing results...
# [9.2s] Construction completed!
# Processing sample 19/50...
# [0.0s] Starting knowledge graph construction...
# [2.6s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.0s] Extracting entities and relations...
# [13.8s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [15.1s] Finalizing results...
# [15.1s] Construction completed!
# Processing sample 20/50...
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.0s] Extracting entities and relations...
# [8.0s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [9.7s] Finalizing results...
# [9.7s] Construction completed!
# Progress saved: 20/50
# Processing sample 21/50...
# [0.0s] Starting knowledge graph construction...
# [2.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.2s] Extracting entities and relations...
# [9.4s] NER completed: 4 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [10.8s] Finalizing results...
# [10.8s] Construction completed!
# Sample 21/50]
# Processing sample 22/50...
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.3s] Extracting entities and relations...
# [16.3s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [18.4s] Finalizing results...
# [18.4s] Construction completed!
# Processing sample 23/50...
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.8s] Extracting entities and relations...
# [9.9s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [11.5s] Finalizing results...
# [11.5s] Construction completed!
# Processing sample 24/50...
# [0.0s] Starting knowledge graph construction...
# [2.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [14.7s] Extracting entities and relations...
# [22.1s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [23.0s] Finalizing results...
# [23.0s] Construction completed!
# Processing sample 25/50...
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.4s] Extracting entities and relations...
# [7.4s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [9.8s] Extracting entities and relations...
# [15.6s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [18.5s] Extracting entities and relations...
# [21.5s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [23.1s] Extracting entities and relations...
# [26.8s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [28.5s] Finalizing results...
# [28.5s] Construction completed!
# Progress saved: 25/50
# Processing sample 26/50...
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [10.6s] Extracting entities and relations...
# [16.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [17.6s] Finalizing results...
# [17.6s] Construction completed!
# Processing sample 27/50...
# [0.0s] Starting knowledge graph construction...
# [4.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [7.6s] Extracting entities and relations...
# [13.9s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [15.6s] Extracting entities and relations...
# [22.8s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [27.0s] Finalizing results...
# [27.0s] Construction completed!
# Processing sample 28/50...
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.6s] Extracting entities and relations...
# [8.4s] NER completed: 3 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [10.0s] Finalizing results...
# [10.0s] Construction completed!
# Processing sample 29/50...
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.0s] Extracting entities and relations...
# [7.5s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [9.6s] Finalizing results...
# [9.6s] Construction completed!
# Processing sample 30/50...
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.9s] Extracting entities and relations...
# [8.4s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [11.5s] Finalizing results...
# [11.5s] Construction completed!
# Progress saved: 30/50
# Processing sample 31/50...
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.6s] Extracting entities and relations...
# [8.9s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [11.1s] Finalizing results...
# [11.1s] Construction completed!
# Processing sample 32/50...
# [0.0s] Starting knowledge graph construction...
# [7.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [11.2s] Extracting entities and relations...
# [15.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [16.9s] Finalizing results...
# [16.9s] Construction completed!
# Processing sample 33/50...
# [0.0s] Starting knowledge graph construction...
# [1.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.2s] Extracting entities and relations...
# [10.1s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [11.2s] Finalizing results...
# [11.2s] Construction completed!
# Processing sample 34/50...
# [0.0s] Starting knowledge graph construction...
# [2.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.3s] Extracting entities and relations...
# [8.7s] NER completed: 21 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 21/21 entities, 0/0 triples
# [10.2s] Extracting entities and relations...
# [16.2s] NER completed: 21 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 21/21 entities, 0/0 triples
# [17.2s] Finalizing results...
# [17.2s] Construction completed!
# Processing sample 35/50...
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [5.8s] Extracting entities and relations...
# [21.6s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [24.2s] Extracting entities and relations...
# [29.2s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [30.9s] Finalizing results...
# [30.9s] Construction completed!
# Progress saved: 35/50
# Processing sample 36/50...
# [0.0s] Starting knowledge graph construction...
# [3.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.4s] Extracting entities and relations...
# [8.8s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [12.4s] Extracting entities and relations...
# [17.6s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [19.1s] Finalizing results...
# [19.1s] Construction completed!
# Processing sample 37/50...
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.5s] Extracting entities and relations...
# [8.3s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [9.6s] Finalizing results...
# [9.7s] Construction completed!
# Processing sample 38/50...
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.5s] Extracting entities and relations...
# [9.6s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [11.0s] Finalizing results...
# [11.0s] Construction completed!
# Processing sample 39/50...
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.8s] Extracting entities and relations...
# [7.3s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [8.8s] Finalizing results...
# [8.8s] Construction completed!
# Processing sample 40/50...
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.8s] Extracting entities and relations...
# [8.7s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [10.0s] Finalizing results...
# [10.0s] Construction completed!
# Progress saved: 40/50
# Processing sample 41/50...
# [0.0s] Starting knowledge graph construction...
# [2.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.5s] Extracting entities and relations...
# [8.2s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [9.8s] Finalizing results...
# [9.8s] Construction completed!
# Sample 41/50]
# Processing sample 42/50...
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.7s] Extracting entities and relations...
# [7.4s] NER completed: 3 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [8.2s] Finalizing results...
# [8.2s] Construction completed!
# Processing sample 43/50...
# [0.0s] Starting knowledge graph construction...
# [5.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [8.2s] Extracting entities and relations...
# [13.6s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [15.2s] Finalizing results...
# [15.2s] Construction completed!
# Processing sample 44/50...
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.8s] Extracting entities and relations...
# [8.7s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [10.2s] Finalizing results...
# [10.2s] Construction completed!
# Processing sample 45/50...
# [0.0s] Starting knowledge graph construction...
# [8.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [9.9s] Extracting entities and relations...
# [13.0s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [14.3s] Finalizing results...
# [14.3s] Construction completed!
# Progress saved: 45/50
# Processing sample 46/50...
# [0.0s] Starting knowledge graph construction...
# [3.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.0s] Extracting entities and relations...
# [9.4s] NER completed: 1 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [11.2s] Finalizing results...
# [11.2s] Construction completed!
# Processing sample 47/50...
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.0s] Extracting entities and relations...
# [8.9s] NER completed: 14 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 14/14 entities, 0/0 triples
# [10.5s] Finalizing results...
# [10.5s] Construction completed!
# Processing sample 48/50...
# [0.0s] Starting knowledge graph construction...
# [2.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [4.2s] Extracting entities and relations...
# [14.1s] NER completed: 13 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 13/13 entities, 0/0 triples
# [16.6s] Finalizing results...
# [16.6s] Construction completed!
# Processing sample 49/50...
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [2.7s] Extracting entities and relations...
# [6.9s] NER completed: 0 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 0/0 entities, 0/0 triples
# [9.2s] Finalizing results...
# [9.2s] Construction completed!
# Processing sample 50/50...
# [0.0s] Starting knowledge graph construction...
# [1.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined conllpp ontology (no LLM call needed)
# [3.7s] Extracting entities and relations...
# [6.7s] NER completed: 2 entities
# [SKIP] Relation extraction disabled for faster NER testing
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [8.1s] Finalizing results...
# [8.1s] Construction completed!
# Progress saved: 50/50
# FINAL EXTRACTION: 91 System Entities, 145 Gold Entities
# Saved Final Triples to JSON files

# %% [markdown]
# ### Micro F1 Metrics

# %%
# Calculate micro F1
precision = total_tp / (total_tp + total_fp) if total_tp + total_fp > 0 else 0
recall = total_tp / (total_tp + total_fn) if total_tp + total_fn > 0 else 0  
f1 = 2 * precision * recall / (precision + recall) if precision + recall > 0 else 0

print(f"\nMicro F1 Results ({rows} samples):")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1: {f1:.3f}")
# Out:
# Micro F1 Results (3453 samples):
# Precision: 0.686
# Recall: 0.638
# F1: 0.661
