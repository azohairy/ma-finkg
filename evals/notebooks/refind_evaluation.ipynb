# %%
import json 
import pandas as pd

# %%
# REFinD Dataset - Load data files
refind_data_path = "../../datasets/refind"

refind_files = {
    "train": f"{refind_data_path}/train_refind_official.json",
    "test": f"{refind_data_path}/test_refind_official.json", 
    "dev": f"{refind_data_path}/dev_refind_official.json"
}

print("REFinD dataset files:")
for split, path in refind_files.items():
    print(f"{split}: {path}")
# Out:
# REFinD dataset files:
# train: ../../datasets/refind/train_refind_official.json
# test: ../../datasets/refind/test_refind_official.json
# dev: ../../datasets/refind/dev_refind_official.json

# %%
# Load refind dataset splits
with open(refind_files["train"], 'r') as f:
    refind_train = json.load(f)
    
with open(refind_files["test"], 'r') as f:
    refind_test = json.load(f)
    
with open(refind_files["dev"], 'r') as f:
    refind_dev = json.load(f)

print(f"Dataset sizes: Train={len(refind_train)}, Test={len(refind_test)}, Dev={len(refind_dev)}")
# Out:
# Dataset sizes: Train=20070, Test=4300, Dev=4306

# %%
def preprocess_refind_data(refind_data):
    processed_samples = []
    
    for idx, sample in enumerate(refind_data):
        # Convert tokens to sentence
        sentence = " ".join(sample['token'])
        
        # Extract entities from e1 and e2
        entities = []
        
        # Entity 1
        e1_text = " ".join(sample['token'][sample['e1_start']:sample['e1_end']])
        entities.append({
            'text': e1_text,
            'type': sample['e1_type'],
            'start': sample['e1_start'], 
            'end': sample['e1_end']
        })
        
        # Entity 2  
        e2_text = " ".join(sample['token'][sample['e2_start']:sample['e2_end']])
        entities.append({
            'text': e2_text,
            'type': sample['e2_type'],
            'start': sample['e2_start'],
            'end': sample['e2_end']
        })
        
        # Extract relations 
        relations = []
        if sample['relation'] != 'no_relation':
            relations.append({
                'head_id': 0,  # e1 is head
                'tail_id': 1,  # e2 is tail
                'type': sample['relation']
            })
        
        processed_samples.append({
            'sentence': sentence,
            'entities': entities,
            'relations': relations,
            'gold_relation': sample['relation'],  # Keep original for strict F1
            'orig_id': sample.get('id', idx)
        })
    
    return processed_samples

# Test preprocessing on small sample
test_sample = preprocess_refind_data(refind_test[:5])
print("Preprocessed REFinD samples (including no_relation):")
for i, sample in enumerate(test_sample):
    print(f"\nSample {i+1}:")
    print(f"Sentence: {sample['sentence'][:80]}...")
    print(f"Gold relation: {sample['gold_relation']}")
    print(f"Entities: {len(sample['entities'])}")
    for j, entity in enumerate(sample['entities']):
        print(f"  Entity {j+1}: '{entity['text']}' ({entity['type']})")
    print(f"Relations: {len(sample['relations'])}")
    for relation in sample['relations']:
        print(f"  Relation: {sample['entities'][relation['head_id']]['text']} -> {relation['type']} -> {sample['entities'][relation['tail_id']]['text']}")
    if not sample['relations']:
        print("  (No relations - gold is no_relation)")
# Out:
# Preprocessed REFinD samples (including no_relation):
#
# Sample 1:
# Sentence: other changes in the financial condition or future prospects of issuers of secur...
# Gold relation: no_relation
# Entities: 2
#   Entity 1: 'Best Hometown Bancorp , Inc.' (ORG)
#   Entity 2: 'FHLB' (ORG)
# Relations: 0
#   (No relations - gold is no_relation)
#
# Sample 2:
# Sentence: eWELLNESS HEALTHCARE Corp also agreed to change eWELLNESS HEALTHCARE Corp. name ...
# Gold relation: no_relation
# Entities: 2
#   Entity 1: 'eWELLNESS HEALTHCARE Corp' (ORG)
#   Entity 2: 'eWellness Healthcare Corporation' (ORG)
# Relations: 0
#   (No relations - gold is no_relation)
#
# Sample 3:
# Sentence: eWELLNESS HEALTHCARE Corp also agreed to change eWELLNESS HEALTHCARE Corp. name ...
# Gold relation: no_relation
# Entities: 2
#   Entity 1: 'eWELLNESS HEALTHCARE Corp.' (ORG)
#   Entity 2: 'eWellness Healthcare Corporation' (ORG)
# Relations: 0
#   (No relations - gold is no_relation)
#
# Sample 4:
# Sentence: above and if the Huawei Contract as described in 5.c above is consummated and th...
# Gold relation: no_relation
# Entities: 2
#   Entity 1: 'YOU ON DEMAND HOLDINGS , INC .' (ORG)
#   Entity 2: 'Huawei Contract' (ORG)
# Relations: 0
#   (No relations - gold is no_relation)
#
# Sample 5:
# Sentence: above and if the Huawei Contract as described in 5.c above is consummated and th...
# Gold relation: no_relation
# Entities: 2
#   Entity 1: 'Huawei Contract' (ORG)
#   Entity 2: 'YOU ON DEMAND HOLDINGS , INC .' (ORG)
# Relations: 0
#   (No relations - gold is no_relation)

# %%
# Preprocess all REFinD dataset splits  
refind_train_processed = preprocess_refind_data(refind_train)
refind_test_processed = preprocess_refind_data(refind_test)
refind_dev_processed = preprocess_refind_data(refind_dev)

print("Preprocessed dataset sizes:")
print(f"Train: {len(refind_train_processed)} samples")
print(f"Test: {len(refind_test_processed)} samples") 
print(f"Dev: {len(refind_dev_processed)} samples")
# Out:
# Preprocessed dataset sizes:
# Train: 20070 samples
# Test: 4300 samples
# Dev: 4306 samples

# %%
# Stratified sampling for REFinD evaluation
import numpy as np
from collections import Counter
import random

def stratified_sample_refind(data, target_size=855, min_per_class=5, random_state=42):
    random.seed(random_state)
    np.random.seed(random_state)
    
    # Group by relation type
    relation_groups = {}
    for sample in data:
        rel_type = sample['gold_relation']
        if rel_type not in relation_groups:
            relation_groups[rel_type] = []
        relation_groups[rel_type].append(sample)
    
    print("=== RELATION TYPE DISTRIBUTION ===")
    total_samples = len(data)
    for rel_type, samples in sorted(relation_groups.items(), key=lambda x: len(x[1]), reverse=True):
        pct = len(samples) / total_samples * 100
        print(f"{rel_type:25s}: {len(samples):4d} ({pct:5.1f}%)")
    
    sampled_data = []
    total_allocated = 0
    
    print(f"\n=== STRATIFIED SAMPLING (Target: {target_size}) ===")
    
    # First pass: Ensure minimum per class
    remaining_budget = target_size
    for rel_type, samples in relation_groups.items():
        if len(samples) < min_per_class:
            allocated = len(samples)
            sampled_data.extend(samples)
        else:
            allocated = min_per_class
            sampled_data.extend(random.sample(samples, allocated))
        
        remaining_budget -= allocated
        total_allocated += allocated
        print(f"{rel_type:25s}: {allocated:3d} samples (minimum)")
    
    # Second pass: Distribute remaining budget proportionally
    if remaining_budget > 0:
        print(f"\nDistributing remaining {remaining_budget} samples proportionally...")
        
        for rel_type, samples in relation_groups.items():
            if len(samples) >= min_per_class: 
                proportion = len(samples) / total_samples
                additional = min(
                    int(remaining_budget * proportion),
                    len(samples) - min_per_class 
                )
                
                if additional > 0:
                    available_samples = [s for s in samples if s not in sampled_data]
                    if available_samples:
                        additional_samples = random.sample(available_samples, min(additional, len(available_samples)))
                        sampled_data.extend(additional_samples)
                        total_allocated += len(additional_samples)
                        print(f"{rel_type:25s}: +{len(additional_samples):2d} samples (proportional)")
    
    print(f"\n=== FINAL STRATIFIED SAMPLE ===")
    print(f"Total sampled: {len(sampled_data)} / {target_size} target")
    
    # Verify distribution
    sampled_relations = Counter([s['gold_relation'] for s in sampled_data])
    for rel_type, count in sorted(sampled_relations.items(), key=lambda x: x[1], reverse=True):
        original_count = len(relation_groups[rel_type])
        pct_sampled = count / original_count * 100
        print(f"{rel_type:25s}: {count:3d}/{original_count:3d} ({pct_sampled:5.1f}%)")
    
    return sampled_data

# Apply stratified sampling
SAMPLE_SIZE = 855

print("Applying stratified sampling to REFinD test set...")
refind_test_sampled = stratified_sample_refind(
    refind_test_processed, 
    target_size=SAMPLE_SIZE,
    min_per_class=5
)

print(f"\n✅ Use refind_test_sampled ({len(refind_test_sampled)} samples) for evaluation")
print("✅ Maintains statistical validity with proper class representation")
# Out:
# Applying stratified sampling to REFinD test set...
# === RELATION TYPE DISTRIBUTION ===
# no_relation              : 1953 ( 45.4%)
# pers:title:title         :  671 ( 15.6%)
# org:gpe:operations_in    :  605 ( 14.1%)
# pers:org:employee_of     :  374 (  8.7%)
# org:org:agreement_with   :  141 (  3.3%)
# org:date:formed_on       :   96 (  2.2%)
# pers:org:member_of       :   95 (  2.2%)
# org:org:subsidiary_of    :   83 (  1.9%)
# org:org:shares_of        :   61 (  1.4%)
# org:money:revenue_of     :   47 (  1.1%)
# org:money:loss_of        :   31 (  0.7%)
# org:gpe:headquartered_in :   29 (  0.7%)
# org:date:acquired_on     :   24 (  0.6%)
# pers:org:founder_of      :   20 (  0.5%)
# org:gpe:formed_in        :   17 (  0.4%)
# org:org:acquired_by      :   12 (  0.3%)
# pers:univ:employee_of    :   12 (  0.3%)
# pers:gov_agy:member_of   :    8 (  0.2%)
# pers:univ:attended       :    7 (  0.2%)
# org:money:profit_of      :    5 (  0.1%)
# pers:univ:member_of      :    5 (  0.1%)
# org:money:cost_of        :    4 (  0.1%)
#
# === STRATIFIED SAMPLING (Target: 855) ===
# no_relation              :   5 samples (minimum)
# org:org:agreement_with   :   5 samples (minimum)
# org:org:shares_of        :   5 samples (minimum)
# org:org:acquired_by      :   5 samples (minimum)
# org:org:subsidiary_of    :   5 samples (minimum)
# pers:univ:attended       :   5 samples (minimum)
# pers:org:employee_of     :   5 samples (minimum)
# pers:org:member_of       :   5 samples (minimum)
# pers:title:title         :   5 samples (minimum)
# org:gpe:formed_in        :   5 samples (minimum)
# org:gpe:headquartered_in :   5 samples (minimum)
# org:gpe:operations_in    :   5 samples (minimum)
# org:money:revenue_of     :   5 samples (minimum)
# org:money:profit_of      :   5 samples (minimum)
# org:money:loss_of        :   5 samples (minimum)
# org:money:cost_of        :   4 samples (minimum)
# org:date:formed_on       :   5 samples (minimum)
# org:date:acquired_on     :   5 samples (minimum)
# pers:univ:member_of      :   5 samples (minimum)
# pers:org:founder_of      :   5 samples (minimum)
# pers:univ:employee_of    :   5 samples (minimum)
# pers:gov_agy:member_of   :   5 samples (minimum)
#
# Distributing remaining 746 samples proportionally...
# no_relation              : +338 samples (proportional)
# org:org:agreement_with   : +24 samples (proportional)
# org:org:shares_of        : +10 samples (proportional)
# org:org:acquired_by      : + 2 samples (proportional)
# org:org:subsidiary_of    : +14 samples (proportional)
# pers:univ:attended       : + 1 samples (proportional)
# pers:org:employee_of     : +64 samples (proportional)
# pers:org:member_of       : +16 samples (proportional)
# pers:title:title         : +116 samples (proportional)
# org:gpe:formed_in        : + 2 samples (proportional)
# org:gpe:headquartered_in : + 5 samples (proportional)
# org:gpe:operations_in    : +104 samples (proportional)
# org:money:revenue_of     : + 8 samples (proportional)
# org:money:loss_of        : + 5 samples (proportional)
# org:date:formed_on       : +16 samples (proportional)
# org:date:acquired_on     : + 4 samples (proportional)
# pers:org:founder_of      : + 3 samples (proportional)
# pers:univ:employee_of    : + 2 samples (proportional)
# pers:gov_agy:member_of   : + 1 samples (proportional)
#
# === FINAL STRATIFIED SAMPLE ===
# Total sampled: 844 / 855 target
# no_relation              : 343/1953 ( 17.6%)
# pers:title:title         : 121/671 ( 18.0%)
# org:gpe:operations_in    : 109/605 ( 18.0%)
# pers:org:employee_of     :  69/374 ( 18.4%)
# org:org:agreement_with   :  29/141 ( 20.6%)
# pers:org:member_of       :  21/ 95 ( 22.1%)
# org:date:formed_on       :  21/ 96 ( 21.9%)
# org:org:subsidiary_of    :  19/ 83 ( 22.9%)
# org:org:shares_of        :  15/ 61 ( 24.6%)
# org:money:revenue_of     :  13/ 47 ( 27.7%)
# org:gpe:headquartered_in :  10/ 29 ( 34.5%)
# org:money:loss_of        :  10/ 31 ( 32.3%)
# org:date:acquired_on     :   9/ 24 ( 37.5%)
# pers:org:founder_of      :   8/ 20 ( 40.0%)
# org:org:acquired_by      :   7/ 12 ( 58.3%)
# org:gpe:formed_in        :   7/ 17 ( 41.2%)
# pers:univ:employee_of    :   7/ 12 ( 58.3%)
# pers:univ:attended       :   6/  7 ( 85.7%)
# pers:gov_agy:member_of   :   6/  8 ( 75.0%)
# org:money:profit_of      :   5/  5 (100.0%)
# pers:univ:member_of      :   5/  5 (100.0%)
# org:money:cost_of        :   4/  4 (100.0%)
#
# ✅ Use refind_test_sampled (844 samples) for evaluation
# ✅ Maintains statistical validity with proper class representation

# %%
def extract_types_from_split(data, split_name):
    entity_types = set()
    relation_types = set()
    
    for sample in data:
        entity_types.add(sample['e1_type'])
        entity_types.add(sample['e2_type'])
        relation_types.add(sample['relation'])
    
    print(f"{split_name.upper()} SPLIT:")
    print(f"  Entity Types ({len(entity_types)}): {sorted(list(entity_types))}")
    print(f"  Relation Types ({len(relation_types)}): {sorted(list(relation_types))}")
    print(f"  Total Samples: {len(data)}")
    print()
    
    return entity_types, relation_types

# Extract entities & relations from each split
train_entities, train_relations = extract_types_from_split(refind_train, "train")
test_entities, test_relations = extract_types_from_split(refind_test, "test") 
dev_entities, dev_relations = extract_types_from_split(refind_dev, "dev")
# Out:
# TRAIN SPLIT:
#   Entity Types (8): ['DATE', 'GOV_AGY', 'GPE', 'MONEY', 'ORG', 'PERSON', 'TITLE', 'UNIV']
#   Relation Types (22): ['no_relation', 'org:date:acquired_on', 'org:date:formed_on', 'org:gpe:formed_in', 'org:gpe:headquartered_in', 'org:gpe:operations_in', 'org:money:cost_of', 'org:money:loss_of', 'org:money:profit_of', 'org:money:revenue_of', 'org:org:acquired_by', 'org:org:agreement_with', 'org:org:shares_of', 'org:org:subsidiary_of', 'pers:gov_agy:member_of', 'pers:org:employee_of', 'pers:org:founder_of', 'pers:org:member_of', 'pers:title:title', 'pers:univ:attended', 'pers:univ:employee_of', 'pers:univ:member_of']
#   Total Samples: 20070
#
# TEST SPLIT:
#   Entity Types (8): ['DATE', 'GOV_AGY', 'GPE', 'MONEY', 'ORG', 'PERSON', 'TITLE', 'UNIV']
#   Relation Types (22): ['no_relation', 'org:date:acquired_on', 'org:date:formed_on', 'org:gpe:formed_in', 'org:gpe:headquartered_in', 'org:gpe:operations_in', 'org:money:cost_of', 'org:money:loss_of', 'org:money:profit_of', 'org:money:revenue_of', 'org:org:acquired_by', 'org:org:agreement_with', 'org:org:shares_of', 'org:org:subsidiary_of', 'pers:gov_agy:member_of', 'pers:org:employee_of', 'pers:org:founder_of', 'pers:org:member_of', 'pers:title:title', 'pers:univ:attended', 'pers:univ:employee_of', 'pers:univ:member_of']
#   Total Samples: 4300
#
# DEV SPLIT:
#   Entity Types (8): ['DATE', 'GOV_AGY', 'GPE', 'MONEY', 'ORG', 'PERSON', 'TITLE', 'UNIV']
#   Relation Types (22): ['no_relation', 'org:date:acquired_on', 'org:date:formed_on', 'org:gpe:formed_in', 'org:gpe:headquartered_in', 'org:gpe:operations_in', 'org:money:cost_of', 'org:money:loss_of', 'org:money:profit_of', 'org:money:revenue_of', 'org:org:acquired_by', 'org:org:agreement_with', 'org:org:shares_of', 'org:org:subsidiary_of', 'pers:gov_agy:member_of', 'pers:org:employee_of', 'pers:org:founder_of', 'pers:org:member_of', 'pers:title:title', 'pers:univ:attended', 'pers:univ:employee_of', 'pers:univ:member_of']
#   Total Samples: 4306

# %% [markdown]
# ### REFinD Evaluation

# %%
import sys
import os
from datetime import datetime

# Add both the main source and current directory to path
sys.path.append('../../src')
sys.path.append('.')  # For refind_metrics in current directory

from ma_finkg.kg_construction_graph import FinancialKGConstructionGraph
from refind_metrics import evaluate_refind_dual_track, evaluate_track_a_full_pipeline, evaluate_track_b_direct_classification

# Set OpenRouter API key and model
openrouter_key = ""
model = "openai/gpt-4.1-mini"

# Set API key and initialize with REFinD ontology
os.environ["OPENROUTER_API_KEY"] = openrouter_key
kg_system = FinancialKGConstructionGraph(model_name=model, ontology="refind", prompts="refind")

# %%
start_ma = datetime.now()
print("Track A: Full pipeline with span matching (system capability)")
# Track A: Full Pipeline Evaluation
print("\nRunning Track A: Full Pipeline Evaluation...")
track_a_results = evaluate_track_a_full_pipeline(refind_test_sampled, kg_system, max_samples=787)

print(f"\nTRACK A: Full Pipeline (System Capability)")
print(f"  Strict Micro-F1: {track_a_results['strict_f1_relation']['f1']:.3f}")
print(f"  Precision: {track_a_results['strict_f1_relation']['precision']:.3f}")
print(f"  Recall:    {track_a_results['strict_f1_relation']['recall']:.3f}")
print(f"  (TP:{track_a_results['strict_f1_relation']['tp']}, FP:{track_a_results['strict_f1_relation']['fp']}, FN:{track_a_results['strict_f1_relation']['fn']})")
print(f"  True negatives excluded: {track_a_results['true_negatives_excluded']}")
print(f"  NER F1: {track_a_results['ner']['f1']:.3f} (P={track_a_results['ner']['precision']:.3f}, R={track_a_results['ner']['recall']:.3f})")
end_ma = datetime.now()
print(f"Evaluation Duration: {end_ma - start_ma}")
# Out:
# Track A: Full pipeline with span matching (system capability)
#
# Running Track A: Full Pipeline Evaluation...
# Processing sample 1/787...
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.2s] NER completed: 2 entities
# [18.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [19.5s] Finalizing results...
# [19.5s] Construction completed!
# Track A Sample 1: Gold='merk' → 'gmbh' (no_relation)
#   System triples: 0
#   Predicted: no_relation
#   NER: Gold=2, Sys=2, TP=1
#
#
# === DEBUG SAMPLE 1 ===
# Text: ( 3 ) The GmbH shall insure Mr Merk at its own expense against accidents as follows : ....
# Gold relation: no_relation
# Predicted relation: no_relation
# Strict F1 category: TN
#   → EXCLUDED from strict F1 calculation
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.2s] NER completed: 5 entities
# [8.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [10.1s] Finalizing results...
# [10.1s] Construction completed!
# Track A Sample 2: Gold='mirror' → 'mississippi' (no_relation)
#   System triples: 0
#   Predicted: no_relation
#   NER: Gold=2, Sys=5, TP=1
#
#
# === DEBUG SAMPLE 2 ===
# Text: See " 2013 MPSC Rate Order " herein for information related to the July 7 , 2015 Mississippi PSC ord...
# Gold relation: no_relation
# Predicted relation: no_relation
# Strict F1 category: TN
#   → EXCLUDED from strict F1 calculation
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [8.5s] NER completed: 3 entities
# [21.7s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 3/3 entities, 9/9 triples
# [22.5s] Finalizing results...
# [22.5s] Construction completed!
# Track A Sample 3: Gold='ewellness healthcare corp' → 'mavericks' (no_relation)
#   System triples: 9
#     1: 'ewellness healthcare corp' → 'september 28 , 2015' (acquired_on)
#     2: 'mavericks' → 'september 28 , 2015' (acquired_on)
#     3: 'ewellness healthcare corp' → 'september 28 , 2015' (formed_on)
#   Predicted: acquired_by
#   NER: Gold=2, Sys=3, TP=2
#
#
# === DEBUG SAMPLE 3 ===
# Text: On September 28 , 2015 , eWELLNESS HEALTHCARE Corp and Mavericks entered into an amendment to the co...
# Gold relation: no_relation
# Predicted relation: acquired_by
# Strict F1 category: FP
#   → INCLUDED in strict F1 calculation
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [10.2s] NER completed: 25 entities
# [115.3s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 25/25 entities, 10/10 triples
# [116.0s] Finalizing results...
# [116.0s] Construction completed!
#
# === DEBUG SAMPLE 4 ===
# Text: During the quarter ended January 31 , 2017 , the Valuation Committee increased the fair value of MVC...
# Gold relation: no_relation
# Predicted relation: no_relation
# Strict F1 category: TN
#   → EXCLUDED from strict F1 calculation
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.2s] NER completed: 4 entities
# [26.9s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 4/4 entities, 14/14 triples
# [27.6s] Finalizing results...
# [27.6s] Construction completed!
#
# === DEBUG SAMPLE 5 ===
# Text: On August 16 , 2010 , Tonix Sub formed Krele LLC ( Krele ) in the state of Delaware ....
# Gold relation: no_relation
# Predicted relation: acquired_on
# Strict F1 category: FP
#   → INCLUDED in strict F1 calculation
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [24.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [25.2s] Finalizing results...
# [25.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.6s] NER completed: 3 entities
# [20.4s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [21.4s] Finalizing results...
# [21.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.6s] Extracting entities and relations...
# [8.5s] NER completed: 3 entities
# [26.3s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [26.9s] Finalizing results...
# [26.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.4s] NER completed: 8 entities
# [44.0s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 8/8 entities, 14/14 triples
# [44.8s] Finalizing results...
# [44.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.4s] NER completed: 3 entities
# [20.4s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [21.3s] Finalizing results...
# [21.3s] Construction completed!
# Processing sample 11/787...
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [7.8s] NER completed: 1 entities
# [16.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [17.5s] Finalizing results...
# [17.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [20.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [21.2s] Finalizing results...
# [21.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [19.2s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 3/3 entities, 8/8 triples
# [19.8s] Finalizing results...
# [19.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.5s] NER completed: 3 entities
# [19.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 3/3 entities, 2/2 triples
# [19.9s] Finalizing results...
# [19.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.6s] NER completed: 4 entities
# [28.5s] RE completed: 18 filtered triples
#
# [REVISION] Validated: 4/4 entities, 18/18 triples
# [29.4s] Finalizing results...
# [29.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.7s] NER completed: 4 entities
# [24.1s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [25.0s] Finalizing results...
# [25.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [23.5s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [24.6s] Finalizing results...
# [24.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.0s] NER completed: 5 entities
# [34.3s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 5/5 entities, 20/20 triples
# [34.9s] Finalizing results...
# [34.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.8s] Extracting entities and relations...
# [11.2s] NER completed: 25 entities
# [60.3s] RE completed: 44 filtered triples
#
# [REVISION] Validated: 25/25 entities, 37/44 triples
# [61.1s] Finalizing results...
# [61.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 7 entities
# [42.9s] RE completed: 37 filtered triples
#
# [REVISION] Validated: 7/7 entities, 37/37 triples
# [43.6s] Finalizing results...
# [43.6s] Construction completed!
# Processing sample 21/787...
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.9s] NER completed: 5 entities
# [50.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [51.6s] Finalizing results...
# [51.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.2s] NER completed: 3 entities
# [18.8s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 3/3 entities, 3/3 triples
# [19.5s] Finalizing results...
# [19.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.1s] NER completed: 5 entities
# [34.1s] RE completed: 36 filtered triples
#
# [REVISION] Validated: 5/5 entities, 36/36 triples
# [34.9s] Finalizing results...
# [34.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.5s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [28.5s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 5/5 entities, 14/14 triples
# [29.3s] Finalizing results...
# [29.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.6s] NER completed: 4 entities
# [25.9s] RE completed: 13 filtered triples
#
# [REVISION] Validated: 4/4 entities, 13/13 triples
# [26.9s] Finalizing results...
# [26.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.4s] NER completed: 8 entities
# [32.1s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 8/8 entities, 14/14 triples
# [32.8s] Finalizing results...
# [32.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [24.8s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [25.5s] Finalizing results...
# [25.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.5s] NER completed: 8 entities
# [40.3s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 8/8 entities, 6/6 triples
# [41.2s] Finalizing results...
# [41.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.1s] NER completed: 8 entities
# [29.9s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 8/8 entities, 6/6 triples
# [30.7s] Finalizing results...
# [30.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.4s] NER completed: 8 entities
# [58.4s] RE completed: 64 filtered triples
#
# [REVISION] Validated: 8/8 entities, 64/64 triples
# [59.1s] Finalizing results...
# [59.1s] Construction completed!
# Processing sample 31/787...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.5s] NER completed: 7 entities
# [34.8s] RE completed: 15 filtered triples
#
# [REVISION] Validated: 7/7 entities, 15/15 triples
# [35.7s] Finalizing results...
# [35.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.0s] NER completed: 7 entities
# [28.8s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 7/7 entities, 7/7 triples
# [29.5s] Finalizing results...
# [29.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.1s] NER completed: 5 entities
# [21.0s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [21.8s] Finalizing results...
# [21.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.3s] NER completed: 4 entities
# [20.8s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [21.6s] Finalizing results...
# [21.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.3s] NER completed: 11 entities
# [46.2s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 11/11 entities, 14/14 triples
# [46.9s] Finalizing results...
# [46.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.7s] NER completed: 5 entities
# [21.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [22.0s] Finalizing results...
# [22.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.0s] NER completed: 11 entities
# [35.9s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 11/11 entities, 5/5 triples
# [37.1s] Finalizing results...
# [37.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [8.6s] NER completed: 8 entities
# [23.9s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 8/8 entities, 8/8 triples
# [24.8s] Finalizing results...
# [24.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [9.0s] NER completed: 6 entities
# [35.7s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [36.8s] Finalizing results...
# [36.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [6.9s] NER completed: 5 entities
# [19.7s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [20.9s] Finalizing results...
# [20.9s] Construction completed!
# Processing sample 41/787...
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.2s] NER completed: 3 entities
# [10.2s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [10.8s] Finalizing results...
# [10.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.7s] NER completed: 8 entities
# [20.9s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 8/8 entities, 7/7 triples
# [21.8s] Finalizing results...
# [21.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.9s] NER completed: 5 entities
# [21.7s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [22.4s] Finalizing results...
# [22.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [9.5s] NER completed: 24 entities
# [53.6s] RE completed: 33 filtered triples
#
# [REVISION] Validated: 24/24 entities, 33/33 triples
# [54.2s] Finalizing results...
# [54.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [31.3s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 6/6 entities, 5/5 triples
# [32.6s] Finalizing results...
# [32.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.3s] NER completed: 7 entities
# [40.8s] RE completed: 13 filtered triples
#
# [REVISION] Validated: 7/7 entities, 13/13 triples
# [42.2s] Finalizing results...
# [42.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.3s] NER completed: 5 entities
# [28.9s] RE completed: 23 filtered triples
#
# [REVISION] Validated: 5/5 entities, 23/23 triples
# [29.9s] Finalizing results...
# [29.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.9s] NER completed: 4 entities
# [23.7s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [24.7s] Finalizing results...
# [24.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [29.2s] RE completed: 15 filtered triples
#
# [REVISION] Validated: 4/4 entities, 15/15 triples
# [30.0s] Finalizing results...
# [30.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.7s] NER completed: 4 entities
# [34.7s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 4/4 entities, 10/10 triples
# [35.6s] Finalizing results...
# [35.6s] Construction completed!
# Processing sample 51/787...
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.2s] NER completed: 6 entities
# [37.2s] RE completed: 18 filtered triples
#
# [REVISION] Validated: 6/6 entities, 18/18 triples
# [37.9s] Finalizing results...
# [37.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [20.7s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 3/3 entities, 10/10 triples
# [21.7s] Finalizing results...
# [21.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.7s] NER completed: 4 entities
# [16.2s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 4/4 entities, 3/3 triples
# [17.0s] Finalizing results...
# [17.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.5s] NER completed: 3 entities
# [17.2s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 3/3 entities, 6/6 triples
# [17.9s] Finalizing results...
# [17.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.5s] NER completed: 5 entities
# [22.3s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 5/5 entities, 16/16 triples
# [22.9s] Finalizing results...
# [22.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.2s] NER completed: 11 entities
# [17.6s] RE completed: 30 filtered triples
#
# [REVISION] Validated: 11/11 entities, 30/30 triples
# [18.4s] Finalizing results...
# [18.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 2 entities
# [12.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [13.3s] Finalizing results...
# [13.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 2 entities
# [16.8s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 2/2 entities, 3/3 triples
# [17.7s] Finalizing results...
# [17.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.4s] NER completed: 4 entities
# [23.4s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 4/4 entities, 20/20 triples
# [24.2s] Finalizing results...
# [24.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.4s] NER completed: 5 entities
# [23.5s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [24.4s] Finalizing results...
# [24.4s] Construction completed!
# Processing sample 61/787...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [9.1s] NER completed: 6 entities
# [24.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 6/6 entities, 0/0 triples
# [25.2s] Finalizing results...
# [25.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.6s] NER completed: 7 entities
# [33.0s] RE completed: 28 filtered triples
#
# [REVISION] Validated: 7/7 entities, 28/28 triples
# [33.9s] Finalizing results...
# [33.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.0s] NER completed: 5 entities
# [23.9s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [24.8s] Finalizing results...
# [24.8s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [22.0s] NER completed: 5 entities
# [36.2s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [37.3s] Finalizing results...
# [37.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.2s] NER completed: 6 entities
# [22.2s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 6/6 entities, 14/14 triples
# [23.2s] Finalizing results...
# [23.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.4s] Extracting entities and relations...
# [8.5s] NER completed: 5 entities
# [8.5s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [9.4s] Finalizing results...
# [9.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.7s] NER completed: 5 entities
# [22.3s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [23.2s] Finalizing results...
# [23.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.4s] NER completed: 6 entities
# [23.2s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 6/6 entities, 12/12 triples
# [24.2s] Finalizing results...
# [24.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.7s] NER completed: 5 entities
# [8.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [9.4s] Finalizing results...
# [9.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.1s] NER completed: 6 entities
# [24.3s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 6/6 entities, 12/12 triples
# [25.2s] Finalizing results...
# [25.2s] Construction completed!
# Processing sample 71/787...
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.2s] NER completed: 6 entities
# [23.7s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 6/6 entities, 8/8 triples
# [24.6s] Finalizing results...
# [24.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.6s] NER completed: 4 entities
# [21.8s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [22.9s] Finalizing results...
# [22.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [8.1s] NER completed: 4 entities
# [22.6s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [23.6s] Finalizing results...
# [23.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [7.7s] NER completed: 4 entities
# [21.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/6 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.3s] NER completed: 6 entities
# [22.8s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [23.5s] Finalizing results...
# [23.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.0s] NER completed: 5 entities
# [21.2s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [22.1s] Finalizing results...
# [22.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.3s] NER completed: 7 entities
# [23.2s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 7/7 entities, 20/20 triples
# [24.1s] Finalizing results...
# [24.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [8.3s] NER completed: 5 entities
# [22.6s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 5/5 entities, 3/3 triples
# [23.4s] Finalizing results...
# [23.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.6s] Extracting entities and relations...
# [8.5s] NER completed: 6 entities
# [21.2s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 6/6 entities, 12/12 triples
# [22.4s] Finalizing results...
# [22.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.8s] NER completed: 3 entities
# [23.8s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [25.3s] Finalizing results...
# [25.3s] Construction completed!
# Processing sample 81/787...
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.9s] NER completed: 4 entities
# [20.0s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 4/4 entities, 12/12 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [20.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [20.9s] Finalizing results...
# [20.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.6s] NER completed: 3 entities
# [13.3s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 3/3 entities, 2/2 triples
# [14.2s] Finalizing results...
# [14.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.0s] NER completed: 3 entities
# [19.3s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 3/3 entities, 3/3 triples
# [20.1s] Finalizing results...
# [20.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [8.0s] NER completed: 5 entities
# [40.9s] RE completed: 28 filtered triples
#
# [REVISION] Validated: 5/5 entities, 28/28 triples
# [41.7s] Finalizing results...
# [41.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.7s] NER completed: 4 entities
# [31.5s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 4/4 entities, 14/14 triples
# [32.9s] Finalizing results...
# [32.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.0s] Extracting entities and relations...
# [8.7s] NER completed: 4 entities
# [22.0s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 4/4 entities, 7/7 triples
# [22.9s] Finalizing results...
# [22.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.1s] NER completed: 4 entities
# [38.2s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 4/4 entities, 8/8 triples
# [39.0s] Finalizing results...
# [39.0s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [27.4s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 4/4 entities, 11/11 triples
# [28.2s] Finalizing results...
# [28.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [7.4s] NER completed: 6 entities
# [20.5s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 6/6 entities, 2/2 triples
# [21.6s] Finalizing results...
# [21.6s] Construction completed!
# Processing sample 91/787...
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.9s] NER completed: 6 entities
# [31.6s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 6/6 entities, 11/11 triples
# [32.5s] Finalizing results...
# [32.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.7s] NER completed: 6 entities
# [19.7s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 6/6 entities, 2/2 triples
# [20.4s] Finalizing results...
# [20.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [20.7s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [21.5s] Finalizing results...
# [21.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [34.5s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 6/6 entities, 7/7 triples
# [35.5s] Finalizing results...
# [35.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [20.0s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [20.7s] Finalizing results...
# [20.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# ...
# [7.2s] NER completed: 5 entities
# [43.4s] RE completed: 28 filtered triples
#
# [REVISION] Validated: 5/5 entities, 28/28 triples
# [44.9s] Finalizing results...
# [44.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.3s] NER completed: 4 entities
# [8.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [9.2s] Finalizing results...
# [9.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.9s] NER completed: 5 entities
# [23.5s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [24.3s] Finalizing results...
# [24.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [9.0s] NER completed: 5 entities
# [23.6s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [24.4s] Finalizing results...
# [24.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [2.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.0s] Extracting entities and relations...
# [9.7s] NER completed: 5 entities
# [9.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [10.5s] Finalizing results...
# [10.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.1s] NER completed: 4 entities
# [29.1s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 4/4 entities, 7/7 triples
# [30.2s] Finalizing results...
# [30.2s] Construction completed!
# Processing sample 761/787...
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.3s] NER completed: 4 entities
# [22.4s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 4/4 entities, 10/10 triples
# [23.1s] Finalizing results...
# [23.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.3s] NER completed: 7 entities
# [21.6s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 7/7 entities, 12/12 triples
# [22.4s] Finalizing results...
# [22.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.3s] NER completed: 6 entities
# [23.6s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [24.5s] Finalizing results...
# [24.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.4s] NER completed: 5 entities
# [25.6s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [26.5s] Finalizing results...
# [26.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.4s] NER completed: 6 entities
# [32.9s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 6/6 entities, 9/9 triples
# [34.1s] Finalizing results...
# [34.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.6s] NER completed: 6 entities
# [28.6s] RE completed: 18 filtered triples
#
# [REVISION] Validated: 6/6 entities, 18/18 triples
# [29.3s] Finalizing results...
# [29.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.1s] NER completed: 7 entities
# [40.4s] RE completed: 24 filtered triples
#
# [REVISION] Validated: 7/7 entities, 24/24 triples
# [41.1s] Finalizing results...
# [41.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [18.3s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 5/5 entities, 1/1 triples
# [18.9s] Finalizing results...
# [18.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.4s] NER completed: 4 entities
# [22.7s] RE completed: 18 filtered triples
#
# [REVISION] Validated: 4/4 entities, 18/18 triples
# [23.6s] Finalizing results...
# [23.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.3s] NER completed: 7 entities
# [27.4s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 7/7 entities, 7/7 triples
# [28.2s] Finalizing results...
# [28.2s] Construction completed!
# Processing sample 771/787...
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.6s] NER completed: 11 entities
# [63.5s] RE completed: 47 filtered triples
#
# [REVISION] Validated: 11/11 entities, 47/47 triples
# [64.2s] Finalizing results...
# [64.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [6.4s] NER completed: 5 entities
# [34.6s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 5/5 entities, 14/14 triples
# [35.4s] Finalizing results...
# [35.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.4s] NER completed: 8 entities
# [40.3s] RE completed: 23 filtered triples
#
# [REVISION] Validated: 8/8 entities, 23/23 triples
# [41.1s] Finalizing results...
# [41.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.0s] NER completed: 3 entities
# [21.2s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 3/3 entities, 8/8 triples
# [22.1s] Finalizing results...
# [22.1s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [13.4s] NER completed: 48 entities
# [146.8s] RE completed: 48 filtered triples
#
# [REVISION] Validated: 48/48 entities, 48/48 triples
# [147.5s] Finalizing results...
# [147.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.4s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [20.8s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [21.9s] Finalizing results...
# [21.9s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.7s] NER completed: 3 entities
# [19.1s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [19.7s] Finalizing results...
# [19.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.5s] NER completed: 3 entities
# [25.4s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [26.2s] Finalizing results...
# [26.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [6.8s] NER completed: 3 entities
# [21.6s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [22.5s] Finalizing results...
# [22.5s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [21.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [21.8s] Finalizing results...
# [21.8s] Construction completed!
# Processing sample 781/787...
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [46.5s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 6/6 entities, 20/20 triples
# [47.3s] Finalizing results...
# [47.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.8s] NER completed: 7 entities
# [25.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 7/7 entities, 0/0 triples
# [26.6s] Finalizing results...
# [26.6s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [24.6s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [25.4s] Finalizing results...
# [25.4s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.7s] NER completed: 8 entities
# [23.5s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 8/8 entities, 9/9 triples
# [24.3s] Finalizing results...
# [24.3s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [7.9s] NER completed: 4 entities
# [20.5s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [21.2s] Finalizing results...
# [21.2s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.3s] NER completed: 5 entities
# [32.7s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 5/5 entities, 11/11 triples
# [33.7s] Finalizing results...
# [33.7s] Construction completed!
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.5s] NER completed: 5 entities
# [23.8s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [24.7s] Finalizing results...
# [24.7s] Construction completed!
#
# TRACK A: Full Pipeline (System Capability)
#   Strict Micro-F1: 0.224
#   Precision: 0.350
#   Recall:    0.164
#   (TP:77, FP:143, FN:392)
#   True negatives excluded: 263
#   NER F1: 0.306 (P=0.205, R=0.597)
# Evaluation Duration: 6:08:35.222633

# %%
# Run separate Track A and Track B evaluations

print("Running separate Track A and Track B REFinD evaluations...")
print("Track B: Direct classification (Li et al. comparable)")

# Track B: Direct Classification Evaluation  
print("\nRunning Track B: Direct Classification Evaluation...")
track_b_results = evaluate_track_b_direct_classification(refind_test_sampled, kg_system, max_samples=844)

print(f"\n=== REFinD EVALUATION RESULTS (n={track_a_results['processed_samples']}) ===")

print(f"\nTRACK B: Direct Classification (Li et al. Comparable)")
print(f"  Macro-F1: {track_b_results['macro_f1']:.3f}")
print(f"  Relations evaluated: {track_b_results['num_relations']}")
print(f"  Per-relation breakdown:")
for rel_type, metrics in track_b_results['per_relation_f1'].items():
    if metrics['tp'] > 0 or metrics['fn'] > 0:  # Only show relations that appear
        print(f"    {rel_type}: F1={metrics['f1']:.3f} (P={metrics['precision']:.3f}, R={metrics['recall']:.3f})")

# Summary
print(f"\n=== EVALUATION METHODOLOGY VALIDATION ===")
print(f"Track A: Proper entity pair span matching implemented")
print(f"Track B: Direct classification enables Li et al. comparison") 
print(f"Strict F1: Excludes {track_a_results['true_negatives_excluded']} true negatives")
print(f"Macro-F1: Computed across {track_b_results['num_relations']} relation types")
print(f"NER: Evaluated only in Track A (system capability)")

# Save results to files
import json
results = {
    'track_a': track_a_results,
    'track_b': track_b_results,
    'evaluation_summary': {
        'track_a_micro_f1': track_a_results['strict_f1_relation']['f1'],
        'track_b_macro_f1': track_b_results['macro_f1'],
        'processed_samples': track_a_results['processed_samples']
    }
}

with open('separate_track_refind_results.json', 'w') as f:
    json.dump(results, f, indent=2)
    
print(f"\nResults for {model} saved to separate_track_refind_results.json")
end_ma = datetime.now()
print(f"Evaluation Duration: {end_ma - start_ma}")
# Out:
# Running separate Track A and Track B REFinD evaluations...
# Track B: Direct classification (Li et al. comparable)
#
# Running Track B: Direct Classification Evaluation...
# Track B: Processing sample 1/787...
#
# [ONTOLOGY] Using predefined refind ontology
# Track B Sample 1: 'Merk' → 'GmbH' = no_relation (gold: no_relation)
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.4s] Extracting entities and relations...
# [6.7s] NER completed: 2 entities
# [15.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [16.5s] Finalizing results...
# [16.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# Track B Sample 2: 'Mirror' → 'Mississippi' = no_relation (gold: no_relation)
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.4s] NER completed: 5 entities
# [8.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [9.3s] Finalizing results...
# [9.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# Track B Sample 3: 'eWELLNESS HEALTHCARE Corp' → 'Mavericks' = acquired_by (gold: no_relation)
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.6s] NER completed: 3 entities
# [24.4s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 3/3 entities, 12/12 triples
# [25.0s] Finalizing results...
# [25.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.7s] NER completed: 25 entities
# [116.8s] RE completed: 18 filtered triples
#
# [REVISION] Validated: 25/25 entities, 18/18 triples
# [117.6s] Finalizing results...
# [117.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.6s] NER completed: 4 entities
# [26.0s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 4/4 entities, 10/10 triples
# [26.9s] Finalizing results...
# [26.9s] Construction completed!
# Track B: Processing sample 6/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [24.9s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [25.6s] Finalizing results...
# [25.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.0s] NER completed: 3 entities
# [24.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [25.0s] Finalizing results...
# [25.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.7s] NER completed: 3 entities
# [28.7s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [29.5s] Finalizing results...
# [29.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.0s] NER completed: 8 entities
# [52.0s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 8/8 entities, 11/11 triples
# [52.6s] Finalizing results...
# [52.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.5s] NER completed: 3 entities
# [18.7s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [19.4s] Finalizing results...
# [19.4s] Construction completed!
# Track B: Processing sample 11/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.9s] NER completed: 1 entities
# [15.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 1/1 entities, 0/0 triples
# [16.5s] Finalizing results...
# [16.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [21.7s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [22.4s] Finalizing results...
# [22.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [18.5s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 3/3 entities, 8/8 triples
# [19.3s] Finalizing results...
# [19.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [19.4s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 3/3 entities, 2/2 triples
# [20.4s] Finalizing results...
# [20.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.5s] NER completed: 4 entities
# [31.0s] RE completed: 17 filtered triples
#
# [REVISION] Validated: 4/4 entities, 17/17 triples
# [31.8s] Finalizing results...
# [31.8s] Construction completed!
# Track B: Processing sample 16/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.7s] NER completed: 4 entities
# [22.7s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [23.8s] Finalizing results...
# [23.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.7s] NER completed: 4 entities
# [23.3s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [24.0s] Finalizing results...
# [24.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.5s] NER completed: 6 entities
# [32.9s] RE completed: 26 filtered triples
#
# [REVISION] Validated: 6/6 entities, 26/26 triples
# [33.7s] Finalizing results...
# [33.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.5s] Extracting entities and relations...
# [11.7s] NER completed: 27 entities
# [62.1s] RE completed: 26 filtered triples
#
# [REVISION] Validated: 27/27 entities, 26/26 triples
# [63.0s] Finalizing results...
# [63.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.9s] NER completed: 7 entities
# [44.3s] RE completed: 42 filtered triples
#
# [REVISION] Validated: 7/7 entities, 42/42 triples
# [45.0s] Finalizing results...
# [45.0s] Construction completed!
# Track B: Processing sample 21/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [6.9s] NER completed: 5 entities
# [37.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [38.4s] Finalizing results...
# [38.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.4s] NER completed: 3 entities
# [19.0s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [20.1s] Finalizing results...
# [20.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.0s] NER completed: 5 entities
# [32.6s] RE completed: 36 filtered triples
#
# [REVISION] Validated: 5/5 entities, 36/36 triples
# [33.5s] Finalizing results...
# [33.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.4s] NER completed: 5 entities
# [31.3s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 5/5 entities, 14/14 triples
# [32.0s] Finalizing results...
# [32.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.4s] NER completed: 4 entities
# [22.2s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 4/4 entities, 9/9 triples
# [23.1s] Finalizing results...
# [23.1s] Construction completed!
# Track B: Processing sample 26/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [8.0s] NER completed: 8 entities
# [32.5s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 8/8 entities, 14/14 triples
# [33.4s] Finalizing results...
# [33.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.4s] NER completed: 5 entities
# [27.0s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [27.7s] Finalizing results...
# [27.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.9s] NER completed: 8 entities
# [36.3s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 8/8 entities, 6/6 triples
# [37.1s] Finalizing results...
# [37.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.2s] NER completed: 8 entities
# [29.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 8/8 entities, 6/6 triples
# [30.2s] Finalizing results...
# [30.2s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.6s] NER completed: 9 entities
# [58.7s] RE completed: 68 filtered triples
#
# [REVISION] Validated: 9/9 entities, 68/68 triples
# [59.5s] Finalizing results...
# [59.5s] Construction completed!
# Track B: Processing sample 31/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.1s] NER completed: 8 entities
# [37.3s] RE completed: 15 filtered triples
#
# [REVISION] Validated: 8/8 entities, 15/15 triples
# [38.1s] Finalizing results...
# [38.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.3s] NER completed: 7 entities
# [28.6s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 7/7 entities, 7/7 triples
# [29.4s] Finalizing results...
# [29.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [22.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [22.8s] Finalizing results...
# [22.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [9.0s] NER completed: 3 entities
# [20.9s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 3/3 entities, 4/4 triples
# [21.6s] Finalizing results...
# [21.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.7s] NER completed: 12 entities
# [44.2s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 12/12 entities, 2/2 triples
# [44.8s] Finalizing results...
# [44.8s] Construction completed!
# Track B: Processing sample 36/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.3s] NER completed: 5 entities
# [21.8s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [23.1s] Finalizing results...
# [23.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.5s] NER completed: 11 entities
# [48.1s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 11/11 entities, 6/6 triples
# [48.8s] Finalizing results...
# [48.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.4s] Extracting entities and relations...
# [7.9s] NER completed: 8 entities
# [21.7s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 8/8 entities, 8/8 triples
# [22.7s] Finalizing results...
# [22.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.1s] NER completed: 6 entities
# [30.8s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 6/6 entities, 12/12 triples
# [31.5s] Finalizing results...
# [31.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [20.3s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 4/4 entities, 5/5 triples
# [21.1s] Finalizing results...
# [21.1s] Construction completed!
# Track B: Processing sample 41/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.4s] NER completed: 3 entities
# [8.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 3/3 entities, 0/0 triples
# [9.5s] Finalizing results...
# [9.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.1s] NER completed: 8 entities
# [20.1s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 8/8 entities, 7/7 triples
# [20.8s] Finalizing results...
# [20.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [6.4s] NER completed: 6 entities
# [20.4s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [21.4s] Finalizing results...
# [21.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [9.0s] NER completed: 23 entities
# [55.4s] RE completed: 33 filtered triples
#
# [REVISION] Validated: 23/23 entities, 33/33 triples
# [56.3s] Finalizing results...
# [56.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 6 entities
# [29.5s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 6/6 entities, 5/5 triples
# [30.4s] Finalizing results...
# [30.4s] Construction completed!
# Track B: Processing sample 46/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.4s] NER completed: 7 entities
# [36.5s] RE completed: 13 filtered triples
#
# [REVISION] Validated: 7/7 entities, 13/13 triples
# [37.4s] Finalizing results...
# [37.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [6.7s] NER completed: 5 entities
# [27.1s] RE completed: 21 filtered triples
#
# [REVISION] Validated: 5/5 entities, 21/21 triples
# [28.0s] Finalizing results...
# [28.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [6.9s] NER completed: 4 entities
# [21.6s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [22.4s] Finalizing results...
# [22.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.3s] NER completed: 4 entities
# [29.5s] RE completed: 17 filtered triples
#
# [REVISION] Validated: 4/4 entities, 17/17 triples
# [30.6s] Finalizing results...
# [30.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.2s] NER completed: 4 entities
# [32.2s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 4/4 entities, 11/11 triples
# [32.9s] Finalizing results...
# [32.9s] Construction completed!
# Track B: Processing sample 51/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.5s] NER completed: 6 entities
# [33.5s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 6/6 entities, 7/7 triples
# [34.1s] Finalizing results...
# [34.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [6.8s] NER completed: 3 entities
# [19.6s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 3/3 entities, 10/10 triples
# [20.6s] Finalizing results...
# [20.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.0s] NER completed: 4 entities
# [14.9s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 4/4 entities, 3/3 triples
# [15.7s] Finalizing results...
# [15.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.5s] NER completed: 3 entities
# [17.3s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 3/3 entities, 6/6 triples
# [18.0s] Finalizing results...
# [18.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [22.4s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 5/5 entities, 16/16 triples
# [23.1s] Finalizing results...
# [23.1s] Construction completed!
# Track B: Processing sample 56/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 11 entities
# [18.9s] RE completed: 30 filtered triples
#
# [REVISION] Validated: 11/11 entities, 30/30 triples
# [19.7s] Finalizing results...
# [19.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.3s] NER completed: 2 entities
# [12.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 2/2 entities, 0/0 triples
# [13.1s] Finalizing results...
# [13.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.0s] NER completed: 3 entities
# [17.0s] RE completed: 3 filtered triples
#
# [REVISION] Validated: 3/3 entities, 3/3 triples
# [17.7s] Finalizing results...
# [17.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.4s] NER completed: 4 entities
# [20.9s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 4/4 entities, 20/20 triples
# [21.8s] Finalizing results...
# [21.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.4s] Extracting entities and relations...
# [6.7s] NER completed: 5 entities
# [21.5s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
# Track B: Processing sample 61/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [8.0s] NER completed: 6 entities
# [22.4s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 6/6 entities, 0/0 triples
# [23.0s] Finalizing results...
# [23.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.7s] NER completed: 7 entities
# [30.4s] RE completed: 27 filtered triples
#
# [REVISION] Validated: 7/7 entities, 27/27 triples
# [31.7s] Finalizing results...
# [31.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.2s] NER completed: 5 entities
# [21.9s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 5/5 entities, 6/6 triples
# [22.8s] Finalizing results...
# [22.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.1s] NER completed: 5 entities
# [21.6s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [6.8s] NER completed: 6 entities
# [19.5s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 6/6 entities, 14/14 triples
# [20.7s] Finalizing results...
# [20.7s] Construction completed!
# Track B: Processing sample 66/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.6s] NER completed: 5 entities
# [7.6s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [8.3s] Finalizing results...
# [8.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.4s] Extracting entities and relations...
# [8.5s] NER completed: 5 entities
# [24.4s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [25.3s] Finalizing results...
# [25.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.0s] NER completed: 6 entities
# [22.0s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 6/6 entities, 12/12 triples
# [22.8s] Finalizing results...
# [22.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.9s] NER completed: 5 entities
# [6.9s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 5/5 entities, 0/0 triples
# [7.9s] Finalizing results...
# [7.9s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [24.4s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [25.8s] Finalizing results...
# [25.8s] Construction completed!
# Track B: Processing sample 71/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.2s] Extracting entities and relations...
# [10.8s] NER completed: 6 entities
# [28.5s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 6/6 entities, 4/4 triples
# [29.3s] Finalizing results...
# [29.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [7.5s] NER completed: 4 entities
# [24.2s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/6 triples
# [24.8s] Finalizing results...
# [24.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [8.1s] NER completed: 4 entities
# [21.8s] RE completed: 1 filtered triples
#
# [REVISION] Validated: 4/4 entities, 1/1 triples
# [22.5s] Finalizing results...
# [22.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [6.9s] NER completed: 4 entities
# [20.5s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 4/4 entities, 6/14 triples
# [21.3s] Finalizing results...
# [21.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.4s] NER completed: 6 entities
# [20.6s] RE completed: 6 filtered triples
#
# [REVISION] Validated: 6/6 entities, 6/6 triples
# [21.3s] Finalizing results...
# [21.3s] Construction completed!
# Track B: Processing sample 76/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.5s] Extracting entities and relations...
# [7.0s] NER completed: 5 entities
# [20.4s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 5/5 entities, 12/12 triples
# [21.2s] Finalizing results...
# [21.2s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 7 entities
# [21.0s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 7/7 entities, 20/20 triples
# [21.7s] Finalizing results...
# [21.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [21.8s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 5/5 entities, 2/2 triples
# [22.5s] Finalizing results...
# [22.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.1s] NER completed: 6 entities
# [19.9s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 6/6 entities, 10/10 triples
# [20.5s] Finalizing results...
# [20.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.2s] NER completed: 4 entities
# [22.1s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [23.0s] Finalizing results...
# [23.0s] Construction completed!
# Track B: Processing sample 81/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.3s] NER completed: 4 entities
# [20.0s] RE completed: 2 filtered triples
#
# [REVISION] Validated: 4/4 entities, 2/2 triples
# [20.9s] Finalizing results...
# [20.9s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [2.3s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.2s] Extracting entities and relations...
# [8.6s] NER completed: 4 entities
# [22.8s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 4/4 entities, 0/0 triples
# [23.5s] Finalizing results...
# [23.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [6.9s] NER completed: 4 entities
# [18.1s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 4/4 entities, 5/5 triples
# [18.9s] Finalizing results...
# [18.9s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [6.9s] NER completed: 3 entities
# [18.2s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [19.1s] Finalizing results...
# [19.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.7s] NER completed: 5 entities
# [34.3s] RE completed: 27 filtered triples
#
# [REVISION] Validated: 5/5 entities, 27/27 triples
# [35.6s] Finalizing results...
# [35.6s] Construction completed!
# Track B: Processing sample 86/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [6.3s] NER completed: 4 entities
# [25.6s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 4/4 entities, 14/14 triples
# [26.3s] Finalizing results...
# [26.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [7.1s] NER completed: 4 entities
# [20.3s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 4/4 entities, 7/7 triples
# [21.0s] Finalizing results...
# [21.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [7.7s] NER completed: 4 entities
# [36.6s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 4/4 entities, 9/9 triples
# [37.4s] Finalizing results...
# [37.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [6.8s] NER completed: 4 entities
# [26.1s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 4/4 entities, 12/12 triples
# [26.9s] Finalizing results...
# [26.9s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# ...
# [31.2s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 4/4 entities, 7/7 triples
# [32.1s] Finalizing results...
# [32.1s] Construction completed!
# Track B: Processing sample 761/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [9.1s] NER completed: 4 entities
# [27.2s] RE completed: 10 filtered triples
#
# [REVISION] Validated: 4/4 entities, 10/10 triples
# [28.1s] Finalizing results...
# [28.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.9s] NER completed: 7 entities
# [26.2s] RE completed: 12 filtered triples
#
# [REVISION] Validated: 7/7 entities, 12/12 triples
# [27.0s] Finalizing results...
# [27.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [10.7s] NER completed: 6 entities
# [30.1s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [31.7s] Finalizing results...
# [31.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [8.5s] NER completed: 5 entities
# [27.9s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [28.8s] Finalizing results...
# [28.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.3s] Extracting entities and relations...
# [10.5s] NER completed: 6 entities
# [36.9s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 6/6 entities, 9/9 triples
# [38.2s] Finalizing results...
# [38.2s] Construction completed!
# Track B: Processing sample 766/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.3s] NER completed: 6 entities
# [27.7s] RE completed: 17 filtered triples
#
# [REVISION] Validated: 6/6 entities, 17/17 triples
# [28.4s] Finalizing results...
# [28.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.0s] NER completed: 7 entities
# [35.4s] RE completed: 30 filtered triples
#
# [REVISION] Validated: 7/7 entities, 30/30 triples
# [36.4s] Finalizing results...
# [36.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [10.3s] NER completed: 5 entities
# [24.9s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [25.9s] Finalizing results...
# [25.9s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.5s] NER completed: 4 entities
# [24.6s] RE completed: 17 filtered triples
#
# [REVISION] Validated: 4/4 entities, 17/17 triples
# [25.4s] Finalizing results...
# [25.4s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.1s] NER completed: 7 entities
# [31.8s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 7/7 entities, 8/8 triples
# [32.5s] Finalizing results...
# [32.5s] Construction completed!
# Track B: Processing sample 771/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.7s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.9s] NER completed: 14 entities
# [67.9s] RE completed: 77 filtered triples
#
# [REVISION] Validated: 14/14 entities, 77/77 triples
# [68.8s] Finalizing results...
# [68.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.5s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.5s] Extracting entities and relations...
# [9.4s] NER completed: 5 entities
# [65.8s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 5/5 entities, 11/11 triples
# [66.6s] Finalizing results...
# [66.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [8.2s] NER completed: 8 entities
# [41.0s] RE completed: 24 filtered triples
#
# [REVISION] Validated: 8/8 entities, 24/24 triples
# [42.1s] Finalizing results...
# [42.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.0s] Extracting entities and relations...
# [8.6s] NER completed: 3 entities
# [24.2s] RE completed: 8 filtered triples
#
# [REVISION] Validated: 3/3 entities, 8/8 triples
# [25.1s] Finalizing results...
# [25.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.1s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.5s] Extracting entities and relations...
# [13.8s] NER completed: 48 entities
# [160.3s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 48/48 entities, 20/20 triples
# [160.9s] Finalizing results...
# [160.9s] Construction completed!
# Track B: Processing sample 776/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.5s] Extracting entities and relations...
# [8.9s] NER completed: 4 entities
# [23.9s] RE completed: 14 filtered triples
#
# [REVISION] Validated: 4/4 entities, 14/14 triples
# [24.6s] Finalizing results...
# [24.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [2.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [3.3s] Extracting entities and relations...
# [9.6s] NER completed: 3 entities
# [23.9s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [24.7s] Finalizing results...
# [24.7s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.9s] Extracting entities and relations...
# [8.4s] NER completed: 3 entities
# [29.3s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [30.8s] Finalizing results...
# [30.8s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.7s] NER completed: 3 entities
# [21.5s] RE completed: 5 filtered triples
#
# [REVISION] Validated: 3/3 entities, 5/5 triples
# [22.3s] Finalizing results...
# [22.3s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [7.8s] NER completed: 5 entities
# [20.4s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 5/5 entities, 4/4 triples
# [21.7s] Finalizing results...
# [21.7s] Construction completed!
# Track B: Processing sample 781/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.2s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.1s] Extracting entities and relations...
# [9.0s] NER completed: 6 entities
# [47.7s] RE completed: 20 filtered triples
#
# [REVISION] Validated: 6/6 entities, 20/20 triples
# [49.1s] Finalizing results...
# [49.1s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.6s] Extracting entities and relations...
# [8.4s] NER completed: 7 entities
# [28.3s] RE completed: 0 filtered triples
#
# [REVISION] Validated: 7/7 entities, 0/0 triples
# [29.2s] Finalizing results...
# [29.2s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.8s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.7s] Extracting entities and relations...
# [7.7s] NER completed: 6 entities
# [27.1s] RE completed: 16 filtered triples
#
# [REVISION] Validated: 6/6 entities, 16/16 triples
# [28.0s] Finalizing results...
# [28.0s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [7.6s] NER completed: 8 entities
# [22.7s] RE completed: 9 filtered triples
#
# [REVISION] Validated: 8/8 entities, 9/9 triples
# [23.6s] Finalizing results...
# [23.6s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [9.6s] NER completed: 4 entities
# [23.2s] RE completed: 4 filtered triples
#
# [REVISION] Validated: 4/4 entities, 4/4 triples
# [24.3s] Finalizing results...
# [24.3s] Construction completed!
# Track B: Processing sample 786/787...
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [1.0s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [2.2s] Extracting entities and relations...
# [8.8s] NER completed: 5 entities
# [35.2s] RE completed: 11 filtered triples
#
# [REVISION] Validated: 5/5 entities, 11/11 triples
# [36.5s] Finalizing results...
# [36.5s] Construction completed!
#
# [ONTOLOGY] Using predefined refind ontology
# [0.0s] Starting knowledge graph construction...
# [0.9s] Creating ontology...
#
# [ONTOLOGY] Using predefined refind ontology
# [1.8s] Extracting entities and relations...
# [8.5s] NER completed: 5 entities
# [29.1s] RE completed: 7 filtered triples
#
# [REVISION] Validated: 5/5 entities, 7/7 triples
# [30.4s] Finalizing results...
# [30.4s] Construction completed!
#
# === REFinD EVALUATION RESULTS (n=787) ===
#
# TRACK B: Direct Classification (Li et al. Comparable)
#   Macro-F1: 0.102
#   Relations evaluated: 18
#   Per-relation breakdown:
#     acquired_by: F1=0.082 (P=0.047, R=0.333)
#     acquired_on: F1=0.235 (P=0.140, R=0.750)
#     agreement_with: F1=0.138 (P=1.000, R=0.074)
#     shares_of: F1=0.000 (P=0.000, R=0.000)
#     subsidiary_of: F1=0.000 (P=0.000, R=0.000)
#     attended: F1=0.000 (P=0.000, R=0.000)
#     employee_of: F1=0.430 (P=0.520, R=0.366)
#     member_of: F1=0.229 (P=1.000, R=0.129)
#     title: F1=0.591 (P=1.000, R=0.420)
#     formed_in: F1=0.027 (P=0.015, R=0.143)
#     headquartered_in: F1=0.000 (P=0.000, R=0.000)
#     operations_in: F1=0.000 (P=0.000, R=0.000)
#     revenue_of: F1=0.000 (P=0.000, R=0.000)
#     cost_of: F1=0.095 (P=0.059, R=0.250)
#     profit_of: F1=0.000 (P=0.000, R=0.000)
#     loss_of: F1=0.000 (P=0.000, R=0.000)
#     formed_on: F1=0.000 (P=0.000, R=0.000)
#     founder_of: F1=0.000 (P=0.000, R=0.000)
#
# === EVALUATION METHODOLOGY VALIDATION ===
# Track A: Proper entity pair span matching implemented
# Track B: Direct classification enables Li et al. comparison
# Strict F1: Excludes 263 true negatives
# Macro-F1: Computed across 18 relation types
# NER: Evaluated only in Track A (system capability)
#
# Results for openai/gpt-4.1-mini saved to separate_track_refind_results.json
# Evaluation Duration: 1 day, 1:18:03.001807
